# %% [markdown]
# # A basic script showing how to frame results and the different options
#
# #### We start by importing the Library

# %%
# import the library
from cmipld import *

# %% [markdown]
# #### Next we can load the JSONLD compacted files:
#
# When loading the data we can use
# - the built in load function to extract the latest versions using the github api
# - absolute file locations
# - file URLs including github raw links
# - github repository (supplied by a list)
# - A combination of the above

# %%
# we can load the latest cmpi6plus and mip table files from github
latest = await CMIPFileUtils.load_latest()

'''
############################################################
# If you want to manually specify the locations you may use:
############################################################

cmip6plus = '<your path>/CMIP6Plus_CVs/compiled/graph_data.json'
mip_cmor_tables = '<your path>/mip-cmor-tables/compiled/graph_data.json'

latest = await CMIPFileUtils.load([cmip6plus, mip_cmor_tables])
'''
''
# Out:
# Loading latest CMIP6Plus and MIP-CMOR-Tables files...
# ''

# %% [markdown]
# #### Deciding on a frame
# Exctracting information requires us to frame our request. Here we can start with asking for all objects of `@type` mip:institution and mip:consortim. These make up our list of consortiums

# %%
frame = {

        # "@context": {},
        
        "@type": [
            "mip:institution",
            "mip:consortium"
        ],
      
        # we also want to ensure any results are embedded in the output
        "@embed":"@always"
}

# %% [markdown]
# To request this information we use the library Frame class:

# %%
data = Frame(latest,frame)

# %% [markdown]
# Lets use pprint to display the results

# %%
data.print
# Out:
# [{'@id': 'mip-cmor-tables:organisations/consortia/miroc',
#   '@type': 'mip:consortium',
#   'consortium:changes': '',
#   'consortium:cmip-acronym': 'MIROC',
#   'consortium:members': [{'@type': 'consortia:member',
#                           'consortium:consortia:membership-type': 'prior',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/jamstec'}},
#                          {'@type': 'consortia:member',
#                           'consortium:consortia:membership-type': 'prior',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/aori'}},
#                          {'@type': 'consortia:member',
#                           'consortium:consortia:membership-type': 'prior',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/nies'}},
#                          {'@type': 'consortia:member',
#                           'consortium:consortia:membership-type': 'prior',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/r-ccs'}}],
#   'consortium:name': 'MIROC Consortium',
#   'consortium:status': 'active',
#   'consortium:url': ''},
#  {'@id': 'mip-cmor-tables:organisations/consortia/ncc',
#   '@type': 'mip:consortium',
#   'consortium:changes': '',
#   'consortium:cmip-acronym': 'NCC',
#   'consortium:members': [{'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/noresm'},
#                           'consortium:membership-type': 'prior'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/met-norway'},
#                           'consortium:membership-type': 'prior'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/nersc'},
#                           'consortium:membership-type': 'prior'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/nilu'},
#                           'consortium:membership-type': 'prior'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/uib'},
#                           'consortium:membership-type': 'prior'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/uio'},
#                           'consortium:membership-type': 'prior'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2016,
#                                                'consortium:phase': 'CMIP6',
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/uni'},
#                           'consortium:membership-type': 'prior'}],
#   'consortium:name': 'NCC Consortium',
#   'consortium:status': 'active',
#   'consortium:url': ''},
#  {'@id': 'mip-cmor-tables:organisations/consortia/solaris-heppa',
#   '@type': 'mip:consortium',
#   'consortium:changes': '',
#   'consortium:cmip-acronym': 'SOLARIS HEPPA',
#   'consortium:members': [{'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2013,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6',
#                                                                     '@type': 'mip:mip-era',
#                                                                     'mip:end': 2024,
#                                                                     'mip:name': 'CMIP6',
#                                                                     'mip:start': 2013,
#                                                                     'mip:url': 'https://wcrp-cmip.org/CMIP6'},
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/auot',
#                                                      '@type': 'mip:institution',
#                                                      'institution:aliases': 'Aristotelian '
#                                                                             'University',
#                                                      'institution:cmip-acronym': 'AUoT',
#                                                      'institution:established': 1925,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/02j61yw88',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Thessaloniki',
#                                                                               'institution:country': ['Greece',
#                                                                                                       'GR'],
#                                                                               'institution:lat': 40.64361,
#                                                                               'institution:lon': 40.64361},
#                                                      'institution:name': 'Aristotle '
#                                                                          'University '
#                                                                          'of '
#                                                                          'Thessaloniki',
#                                                      'institution:ror': '02j61yw88',
#                                                      'institution:type': 'Education',
#                                                      'institution:url': 'https://www.auth.gr/en'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2025,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7',
#                                                                     '@type': 'mip:mip-era',
#                                                                     'mip:end': 2999,
#                                                                     'mip:name': 'CMIP7',
#                                                                     'mip:start': 2025,
#                                                                     'mip:url': 'https://wcrp-cmip.org/CMIP7'},
#                                                'consortium:to': '-'},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/aor',
#                                                      '@type': 'mip:institution',
#                                                      'institution:cmip-acronym': 'AoR',
#                                                      'institution:established': 1938,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/02hnp4676',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Rome',
#                                                                               'institution:country': ['Italy',
#                                                                                                       'IT'],
#                                                                               'institution:lat': 41.921669,
#                                                                               'institution:lon': 41.921669},
#                                                      'institution:name': 'Astronomical '
#                                                                          'Observatory '
#                                                                          'of '
#                                                                          'Rome',
#                                                      'institution:ror': '02hnp4676',
#                                                      'institution:type': 'Facility',
#                                                      'institution:url': 'http://web.oa-roma.inaf.it/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2013,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/bas',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'BAS',
#                                                      'institution:cmip-acronym': 'BAS',
#                                                      'institution:established': 1962,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/01rhff309',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Cambridge',
#                                                                               'institution:country': ['United '
#                                                                                                       'Kingdom',
#                                                                                                       'GB'],
#                                                                               'institution:lat': 52.212965,
#                                                                               'institution:lon': 52.212965},
#                                                      'institution:name': 'British '
#                                                                          'Antarctic '
#                                                                          'Survey',
#                                                      'institution:ror': '01rhff309',
#                                                      'institution:type': 'Government',
#                                                      'institution:url': 'https://www.bas.ac.uk/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2013,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/eawag',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'EAWAG',
#                                                      'institution:cmip-acronym': 'EAWAG',
#                                                      'institution:established': 1936,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/00pc48d59',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Dübendorf',
#                                                                               'institution:country': ['Switzerland',
#                                                                                                       'CH'],
#                                                                               'institution:lat': 47.39724,
#                                                                               'institution:lon': 47.39724},
#                                                      'institution:name': 'Swiss '
#                                                                          'Federal '
#                                                                          'Institute '
#                                                                          'of '
#                                                                          'Aquatic '
#                                                                          'Science '
#                                                                          'and '
#                                                                          'Technology',
#                                                      'institution:ror': '00pc48d59',
#                                                      'institution:type': 'Facility',
#                                                      'institution:url': 'http://www.eawag.ch/en/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/fmi',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'FMI',
#                                                      'institution:cmip-acronym': 'FMI',
#                                                      'institution:established': 1838,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/05hppb561',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Helsinki',
#                                                                               'institution:country': ['Finland',
#                                                                                                       'FI'],
#                                                                               'institution:lat': 60.16952,
#                                                                               'institution:lon': 60.16952},
#                                                      'institution:name': 'Finnish '
#                                                                          'Meteorological '
#                                                                          'Institute',
#                                                      'institution:ror': '05hppb561',
#                                                      'institution:type': 'Government',
#                                                      'institution:url': 'http://en.ilmatieteenlaitos.fi/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2013,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/fuberlin',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'FU',
#                                                      'institution:aliases': ['FU '
#                                                                              'Berlin',
#                                                                              'Free '
#                                                                              'University '
#                                                                              'of '
#                                                                              'Berlin'],
#                                                      'institution:cmip-acronym': 'FUBerlin',
#                                                      'institution:established': 1948,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/046ak2485',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Berlin',
#                                                                               'institution:country': ['Germany',
#                                                                                                       'DE'],
#                                                                               'institution:lat': 52.52437,
#                                                                               'institution:lon': 52.52437},
#                                                      'institution:name': 'Freie '
#                                                                          'Universität '
#                                                                          'Berlin',
#                                                      'institution:ror': '046ak2485',
#                                                      'institution:type': 'Education',
#                                                      'institution:url': 'https://www.fu-berlin.de'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2013,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/geomar'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2013,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/gsfc'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/iaa-csic'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/issi',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'ISSI',
#                                                      'institution:cmip-acronym': 'ISSI',
#                                                      'institution:established': 1995,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/01xm30661',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Bern',
#                                                                               'institution:country': ['Switzerland',
#                                                                                                       'CH'],
#                                                                               'institution:lat': 46.952897,
#                                                                               'institution:lon': 46.952897},
#                                                      'institution:name': 'International '
#                                                                          'Space '
#                                                                          'Science '
#                                                                          'Institute',
#                                                      'institution:ror': '01xm30661',
#                                                      'institution:type': 'Nonprofit',
#                                                      'institution:url': 'http://www.issibern.ch/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/kit',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'KIT',
#                                                      'institution:aliases': ['Karlsruhe '
#                                                                              'Institute '
#                                                                              'of '
#                                                                              'Technology '
#                                                                              '- '
#                                                                              'The '
#                                                                              'Research '
#                                                                              'University '
#                                                                              'in '
#                                                                              'the '
#                                                                              'Helmholtz '
#                                                                              'Association',
#                                                                              'Das '
#                                                                              'Karlsruher '
#                                                                              'Institut '
#                                                                              'für '
#                                                                              'Technologie '
#                                                                              '(KIT) '
#                                                                              '– '
#                                                                              'Die '
#                                                                              'Forschungsuniversität '
#                                                                              'in '
#                                                                              'der '
#                                                                              'Helmholtz-Gemeinschaft'],
#                                                      'institution:cmip-acronym': 'KIT',
#                                                      'institution:established': 2009,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/04t3en479',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Karlsruhe',
#                                                                               'institution:country': ['Germany',
#                                                                                                       'DE'],
#                                                                               'institution:lat': 49.00937,
#                                                                               'institution:lon': 49.00937},
#                                                      'institution:name': 'Karlsruhe '
#                                                                          'Institute '
#                                                                          'of '
#                                                                          'Technology',
#                                                      'institution:ror': '04t3en479',
#                                                      'institution:type': 'Education',
#                                                      'institution:url': 'http://www.kit.edu/english/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/lasp'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/lpc2e',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'LPC2E',
#                                                      'institution:cmip-acronym': 'LPC2E',
#                                                      'institution:established': 2012,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/049k66y27',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Orléans',
#                                                                               'institution:country': ['France',
#                                                                                                       'FR'],
#                                                                               'institution:lat': 47.90289,
#                                                                               'institution:lon': 47.90289},
#                                                      'institution:name': 'Laboratoire '
#                                                                          'de '
#                                                                          'Physique '
#                                                                          'et '
#                                                                          'Chimie '
#                                                                          'de '
#                                                                          'l’Environnement '
#                                                                          'et '
#                                                                          'de '
#                                                                          'l’Espace',
#                                                      'institution:ror': '049k66y27',
#                                                      'institution:type': 'Facility',
#                                                      'institution:url': 'https://www.lpc2e.cnrs.fr'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': {'consortium:from': 2013,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                'consortium:to': 2022},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/mohc',
#                                                      '@type': 'mip:institution',
#                                                      'institution:aliases': 'Meteorological '
#                                                                             'Office',
#                                                      'institution:cmip-acronym': 'MOHC',
#                                                      'institution:established': 1854,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/01ch2yn61',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Exeter',
#                                                                               'institution:country': ['United '
#                                                                                                       'Kingdom',
#                                                                                                       'GB'],
#                                                                               'institution:lat': 50.7236,
#                                                                               'institution:lon': 50.7236},
#                                                      'institution:name': 'Met '
#                                                                          'Office',
#                                                      'institution:ror': '01ch2yn61',
#                                                      'institution:type': 'Government',
#                                                      'institution:url': 'http://www.metoffice.gov.uk/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/mps',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'MPS',
#                                                      'institution:cmip-acronym': 'MPS',
#                                                      'institution:established': 1934,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/02j6gm739',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Göttingen',
#                                                                               'institution:country': ['Germany',
#                                                                                                       'DE'],
#                                                                               'institution:lat': 51.561218,
#                                                                               'institution:lon': 51.561218},
#                                                      'institution:name': 'Max '
#                                                                          'Planck '
#                                                                          'Institute '
#                                                                          'for '
#                                                                          'Solar '
#                                                                          'System '
#                                                                          'Research',
#                                                      'institution:ror': '02j6gm739',
#                                                      'institution:type': 'Facility',
#                                                      'institution:url': 'http://www.mps.mpg.de/en'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/ncar',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'NCAR',
#                                                      'institution:cmip-acronym': 'NCAR',
#                                                      'institution:established': 1930,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/05cvfcr44',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Boulder',
#                                                                               'institution:country': ['United '
#                                                                                                       'States',
#                                                                                                       'US'],
#                                                                               'institution:lat': 40.01499,
#                                                                               'institution:lon': 40.01499},
#                                                      'institution:name': 'National '
#                                                                          'Center '
#                                                                          'for '
#                                                                          'Atmospheric '
#                                                                          'Research',
#                                                      'institution:ror': '05cvfcr44',
#                                                      'institution:type': 'Facility',
#                                                      'institution:url': 'https://ncar.ucar.edu/'},
#                           'consortium:membership-type': 'current'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/pmod',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'PMOD',
#                                                      'institution:cmip-acronym': 'PMOD',
#                                                      'institution:established': 1907,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/02gtrqv93',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Davos',
#                                                                               'institution:country': ['Switzerland',
#                                                                                                       'CH'],
#                                                                               'institution:lat': 46.8133161,
#                                                                               'institution:lon': 46.8133161},
#                                                      'institution:name': 'Physikalisch-Meteorologisches '
#                                                                          'Observatorium '
#                                                                          'Davos',
#                                                      'institution:ror': '02gtrqv93',
#                                                      'institution:type': 'Facility',
#                                                      'institution:url': 'https://www.pmodwrc.ch/'},
#                           'consortium:membership-type': 'current'},
#                          {'consortium:dates': {'consortium:from': 2025,
#                                                'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                'consortium:to': '-'},
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/uobergen',
#                                                      '@type': 'mip:institution',
#                                                      'institution:acronyms': 'UiB',
#                                                      'institution:cmip-acronym': 'UoBergen',
#                                                      'institution:established': 1946,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/03zga2b32',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Bergen',
#                                                                               'institution:country': ['Norway',
#                                                                                                       'NO'],
#                                                                               'institution:lat': 60.39299,
#                                                                               'institution:lon': 60.39299},
#                                                      'institution:name': 'University '
#                                                                          'of '
#                                                                          'Bergen',
#                                                      'institution:ror': '03zga2b32',
#                                                      'institution:type': 'Education',
#                                                      'institution:url': 'http://www.uib.no/'},
#                           'consortium:membership-type': 'current',
#                           'institution:@tyconsortia:pe': 'member'},
#                          {'@type': 'consortia:member',
#                           'consortium:dates': [{'consortium:from': 2013,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip6'},
#                                                 'consortium:to': 2022},
#                                                {'consortium:from': 2025,
#                                                 'consortium:phase': {'@id': 'mip-cmor-tables:auxillary/mip-era/cmip7'},
#                                                 'consortium:to': '-'}],
#                           'consortium:institution': {'@id': 'mip-cmor-tables:organisations/institutions/uoleeds',
#                                                      '@type': 'mip:institution',
#                                                      'institution:cmip-acronym': 'UoLeeds',
#                                                      'institution:established': 1904,
#                                                      'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/024mrxd33',
#                                                                               '@type': 'institution:location',
#                                                                               'institution:city': 'Leeds',
#                                                                               'institution:country': ['United '
#                                                                                                       'Kingdom',
#                                                                                                       'GB'],
# ...
#                            'institution:country': ['Switzerland', 'CH'],
#                            'institution:lat': 46.8133161,
#                            'institution:lon': 46.8133161},
#   'institution:name': 'Physikalisch-Meteorologisches Observatorium Davos',
#   'institution:ror': '02gtrqv93',
#   'institution:type': 'Facility',
#   'institution:url': 'https://www.pmodwrc.ch/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/pnnl-jgcri',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'JGCRI',
#   'institution:cmip-acronym': 'PNNL-JGCRI',
#   'institution:established': 2001,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/058cmd703',
#                            '@type': 'institution:location',
#                            'institution:city': 'Riverdale Park',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 38.971106,
#                            'institution:lon': -76.9217851},
#   'institution:name': 'Joint Global Change Research Institute',
#   'institution:ror': '058cmd703',
#   'institution:type': 'Facility',
#   'institution:url': 'http://www.globalchange.umd.edu/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/pnnl-waccem',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'PNNL',
#   'institution:cmip-acronym': 'PNNL-WACCEM',
#   'institution:established': 1965,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/05h992307',
#                            '@type': 'institution:location',
#                            'institution:city': 'Richland',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 46.28569,
#                            'institution:lon': -119.28446},
#   'institution:name': 'Pacific Northwest National Laboratory',
#   'institution:ror': '05h992307',
#   'institution:type': 'Facility',
#   'institution:url': 'http://www.pnnl.gov/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/rss',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'RSS',
#   'institution:cmip-acronym': 'RSS',
#   'institution:established': 1974,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/01vp8h012',
#                            '@type': 'institution:location',
#                            'institution:city': 'Santa Rosa',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 38.443733,
#                            'institution:lon': -122.717185},
#   'institution:name': 'Remote Sensing Systems (United States)',
#   'institution:ror': '01vp8h012',
#   'institution:type': 'Company',
#   'institution:url': 'http://www.remss.com/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/snu',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'SNU',
#   'institution:aliases': 'Seoul Daehakgyo',
#   'institution:cmip-acronym': 'SNU',
#   'institution:established': 1946,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/04h9pn542',
#                            '@type': 'institution:location',
#                            'institution:city': 'Seoul',
#                            'institution:country': ['South Korea', 'KR'],
#                            'institution:lat': 37.460155,
#                            'institution:lon': 126.951894},
#   'institution:name': 'Seoul National University',
#   'institution:ror': '04h9pn542',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.snu.ac.kr/index.html'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/thu',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'THU',
#   'institution:cmip-acronym': 'THU',
#   'institution:established': 1911,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/03cve4549',
#                            '@type': 'institution:location',
#                            'institution:city': 'Beijing',
#                            'institution:country': ['China', 'CN'],
#                            'institution:lat': 39.999585,
#                            'institution:lon': 116.325414},
#   'institution:name': 'Tsinghua University',
#   'institution:ror': '03cve4549',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.tsinghua.edu.cn/publish/newthuen/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/ua',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UA',
#   'institution:cmip-acronym': 'UA',
#   'institution:established': 1885,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/03m2x1q45',
#                            '@type': 'institution:location',
#                            'institution:city': 'Tucson',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 32.22174,
#                            'institution:lon': -110.92648},
#   'institution:name': 'University of Arizona',
#   'institution:ror': '03m2x1q45',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.arizona.edu/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uci',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UCI',
#   'institution:aliases': 'UC Irvine',
#   'institution:cmip-acronym': 'UCI',
#   'institution:established': 1965,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/04gyf1771',
#                            '@type': 'institution:location',
#                            'institution:city': 'Irvine',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 33.64535,
#                            'institution:lon': -117.842642},
#   'institution:name': 'University of California, Irvine',
#   'institution:ror': '04gyf1771',
#   'institution:type': 'Education',
#   'institution:url': 'http://uci.edu/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/ucolorado',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'CU',
#   'institution:cmip-acronym': 'UColorado',
#   'institution:established': 1876,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/00jc20583',
#                            '@type': 'institution:location',
#                            'institution:city': 'Boulder',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 40.01499,
#                            'institution:lon': -105.27055},
#   'institution:name': 'University of Colorado System',
#   'institution:ror': '00jc20583',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.cu.edu/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/ucsb',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UCSB',
#   'institution:aliases': 'UC Santa Barbara',
#   'institution:cmip-acronym': 'UCSB',
#   'institution:established': 1891,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/02t274463',
#                            '@type': 'institution:location',
#                            'institution:city': 'Santa Barbara',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 34.42083,
#                            'institution:lon': -119.69819},
#   'institution:name': 'University of California, Santa Barbara',
#   'institution:ror': '02t274463',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.ucsb.edu/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uhh',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UHH',
#   'institution:aliases': 'University of Hamburg',
#   'institution:cmip-acronym': 'UHH',
#   'institution:established': 1919,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/00g30e956',
#                            '@type': 'institution:location',
#                            'institution:city': 'Hamburg',
#                            'institution:country': ['Germany', 'DE'],
#                            'institution:lat': 53.55073,
#                            'institution:lon': 9.99302},
#   'institution:name': 'Universität Hamburg',
#   'institution:ror': '00g30e956',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.uni-hamburg.de'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uobergen',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UiB',
#   'institution:cmip-acronym': 'UoBergen',
#   'institution:established': 1946,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/03zga2b32',
#                            '@type': 'institution:location',
#                            'institution:city': 'Bergen',
#                            'institution:country': ['Norway', 'NO'],
#                            'institution:lat': 60.39299,
#                            'institution:lon': 60.39299},
#   'institution:name': 'University of Bergen',
#   'institution:ror': '03zga2b32',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.uib.no/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uofmd',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UMD',
#   'institution:cmip-acronym': 'UofMD',
#   'institution:established': 1856,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/047s2c258',
#                            '@type': 'institution:location',
#                            'institution:city': 'College Park',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 38.98067,
#                            'institution:lon': -76.93692},
#   'institution:name': 'University of Maryland, College Park',
#   'institution:ror': '047s2c258',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.umd.edu/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uoleeds',
#   '@type': 'mip:institution',
#   'institution:cmip-acronym': 'UoLeeds',
#   'institution:established': 1904,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/024mrxd33',
#                            '@type': 'institution:location',
#                            'institution:city': 'Leeds',
#                            'institution:country': ['United Kingdom', 'GB'],
#                            'institution:lat': 53.79648,
#                            'institution:lon': 53.79648},
#   'institution:name': 'University of Leeds',
#   'institution:ror': '024mrxd33',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.leeds.ac.uk/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uom',
#   '@type': 'mip:institution',
#   'institution:aliases': 'Melbourne University',
#   'institution:cmip-acronym': 'UoM',
#   'institution:established': 1853,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/01ej9dk98',
#                            '@type': 'institution:location',
#                            'institution:city': 'Melbourne',
#                            'institution:country': ['Australia', 'AU'],
#                            'institution:lat': -37.814,
#                            'institution:lon': 144.96332},
#   'institution:name': 'University of Melbourne',
#   'institution:ror': '01ej9dk98',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.unimelb.edu.au/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uomontreal',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UdeM',
#   'institution:cmip-acronym': 'UoMontreal',
#   'institution:established': 1878,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/0161xgx34',
#                            '@type': 'institution:location',
#                            'institution:city': 'Montreal',
#                            'institution:country': ['Canada', 'CA'],
#                            'institution:lat': 45.50884,
#                            'institution:lon': 45.50884},
#   'institution:name': 'Université de Montréal',
#   'institution:ror': '0161xgx34',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.umontreal.ca/english/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uootago',
#   '@type': 'mip:institution',
#   'institution:cmip-acronym': 'UoOtago',
#   'institution:established': 1869,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/01jmxt844',
#                            '@type': 'institution:location',
#                            'institution:city': 'Dunedin',
#                            'institution:country': ['New Zealand', 'NZ'],
#                            'institution:lat': -45.87416,
#                            'institution:lon': -45.87416},
#   'institution:name': 'University of Otago',
#   'institution:ror': '01jmxt844',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.otago.ac.nz/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uooulu',
#   '@type': 'mip:institution',
#   'institution:cmip-acronym': 'UoOulu',
#   'institution:established': 1958,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/03yj89h83',
#                            '@type': 'institution:location',
#                            'institution:city': 'Oulu',
#                            'institution:country': ['Finland', 'FI'],
#                            'institution:lat': 65.01236,
#                            'institution:lon': 65.01236},
#   'institution:name': 'University of Oulu',
#   'institution:ror': '03yj89h83',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.oulu.fi/english/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/ureading',
#   '@type': 'mip:institution',
#   'institution:cmip-acronym': 'UReading',
#   'institution:established': 1926,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/05v62cm79',
#                            '@type': 'institution:location',
#                            'institution:city': 'Reading',
#                            'institution:country': ['United Kingdom', 'GB'],
#                            'institution:lat': 51.440832,
#                            'institution:lon': -0.942503},
#   'institution:name': 'University of Reading',
#   'institution:ror': '05v62cm79',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.reading.ac.uk/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/uw',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'UW',
#   'institution:cmip-acronym': 'UW',
#   'institution:established': 1861,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/00cvxb145',
#                            '@type': 'institution:location',
#                            'institution:city': 'Seattle',
#                            'institution:country': ['United States', 'US'],
#                            'institution:lat': 47.60621,
#                            'institution:lon': -122.33207},
#   'institution:name': 'University of Washington',
#   'institution:ror': '00cvxb145',
#   'institution:type': 'Education',
#   'institution:url': 'http://www.washington.edu/'},
#  {'@id': 'mip-cmor-tables:organisations/institutions/vua',
#   '@type': 'mip:institution',
#   'institution:acronyms': 'VU',
#   'institution:aliases': 'VU Amsterdam',
#   'institution:cmip-acronym': 'VUA',
#   'institution:established': 1880,
#   'institution:location': {'@id': 'mip-cmor-tables:organisations/institutions/location/008xxew50',
#                            '@type': 'institution:location',
#                            'institution:city': 'Amsterdam',
#                            'institution:country': ['Netherlands', 'NL'],
#                            'institution:lat': 52.37403,
#                            'institution:lon': 4.88969},
#   'institution:name': 'Vrije Universiteit Amsterdam',
#   'institution:ror': '008xxew50',
#   'institution:type': 'Education',
#   'institution:url': 'https://vu.nl/'}]

# %% [markdown]
# #### Cleaning up the returned object.
# There are a number of ways we can clean up the data, some of these are:
# - untag: removing the tags on keys
# - rmld: removing any id and type tags to result in normal json
# - missing: writes the word "missing" for substituted data which does not exists
# - lower: changes keys to lowercase
# - flatten: converts single entry lists into just the entry.
# - [more functionality being added]

# %%
# lets clean the data using the simplest cleanup methods: rmld and untag
data.clean(['rmld','untag'])

# lets view how the results have changed
data.print
# Out:
# [{'changes': '',
#   'cmip-acronym': 'MIROC',
#   'members': [{'consortia:membership-type': 'prior',
#                'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {}},
#               {'consortia:membership-type': 'prior',
#                'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {}},
#               {'consortia:membership-type': 'prior',
#                'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {}},
#               {'consortia:membership-type': 'prior',
#                'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {}}],
#   'name': 'MIROC Consortium',
#   'status': 'active',
#   'url': ''},
#  {'changes': '',
#   'cmip-acronym': 'NCC',
#   'members': [{'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {},
#                'membership-type': 'prior'},
#               {'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {},
#                'membership-type': 'prior'},
#               {'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {},
#                'membership-type': 'prior'},
#               {'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {},
#                'membership-type': 'prior'},
#               {'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {},
#                'membership-type': 'prior'},
#               {'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {},
#                'membership-type': 'prior'},
#               {'dates': {'from': 2016, 'phase': 'CMIP6', 'to': 2022},
#                'institution': {},
#                'membership-type': 'prior'}],
#   'name': 'NCC Consortium',
#   'status': 'active',
#   'url': ''},
#  {'changes': '',
#   'cmip-acronym': 'SOLARIS HEPPA',
#   'members': [{'dates': {'from': 2013,
#                          'phase': {'mip:end': 2024,
#                                    'mip:name': 'CMIP6',
#                                    'mip:start': 2013,
#                                    'mip:url': 'https://wcrp-cmip.org/CMIP6'},
#                          'to': 2022},
#                'institution': {'aliases': 'Aristotelian University',
#                                'cmip-acronym': 'AUoT',
#                                'established': 1925,
#                                'location': {'city': 'Thessaloniki',
#                                             'country': ['Greece', 'GR'],
#                                             'lat': 40.64361,
#                                             'lon': 40.64361},
#                                'name': 'Aristotle University of Thessaloniki',
#                                'ror': '02j61yw88',
#                                'type': 'Education',
#                                'url': 'https://www.auth.gr/en'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2025,
#                          'phase': {'mip:end': 2999,
#                                    'mip:name': 'CMIP7',
#                                    'mip:start': 2025,
#                                    'mip:url': 'https://wcrp-cmip.org/CMIP7'},
#                          'to': '-'},
#                'institution': {'cmip-acronym': 'AoR',
#                                'established': 1938,
#                                'location': {'city': 'Rome',
#                                             'country': ['Italy', 'IT'],
#                                             'lat': 41.921669,
#                                             'lon': 41.921669},
#                                'name': 'Astronomical Observatory of Rome',
#                                'ror': '02hnp4676',
#                                'type': 'Facility',
#                                'url': 'http://web.oa-roma.inaf.it/'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2013, 'phase': {}, 'to': 2022},
#                'institution': {'acronyms': 'BAS',
#                                'cmip-acronym': 'BAS',
#                                'established': 1962,
#                                'location': {'city': 'Cambridge',
#                                             'country': ['United Kingdom', 'GB'],
#                                             'lat': 52.212965,
#                                             'lon': 52.212965},
#                                'name': 'British Antarctic Survey',
#                                'ror': '01rhff309',
#                                'type': 'Government',
#                                'url': 'https://www.bas.ac.uk/'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2013, 'phase': {}, 'to': 2022},
#                'institution': {'acronyms': 'EAWAG',
#                                'cmip-acronym': 'EAWAG',
#                                'established': 1936,
#                                'location': {'city': 'Dübendorf',
#                                             'country': ['Switzerland', 'CH'],
#                                             'lat': 47.39724,
#                                             'lon': 47.39724},
#                                'name': 'Swiss Federal Institute of Aquatic '
#                                        'Science and Technology',
#                                'ror': '00pc48d59',
#                                'type': 'Facility',
#                                'url': 'http://www.eawag.ch/en/'},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'acronyms': 'FMI',
#                                'cmip-acronym': 'FMI',
#                                'established': 1838,
#                                'location': {'city': 'Helsinki',
#                                             'country': ['Finland', 'FI'],
#                                             'lat': 60.16952,
#                                             'lon': 60.16952},
#                                'name': 'Finnish Meteorological Institute',
#                                'ror': '05hppb561',
#                                'type': 'Government',
#                                'url': 'http://en.ilmatieteenlaitos.fi/'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2013, 'phase': {}, 'to': 2022},
#                'institution': {'acronyms': 'FU',
#                                'aliases': ['FU Berlin',
#                                            'Free University of Berlin'],
#                                'cmip-acronym': 'FUBerlin',
#                                'established': 1948,
#                                'location': {'city': 'Berlin',
#                                             'country': ['Germany', 'DE'],
#                                             'lat': 52.52437,
#                                             'lon': 52.52437},
#                                'name': 'Freie Universität Berlin',
#                                'ror': '046ak2485',
#                                'type': 'Education',
#                                'url': 'https://www.fu-berlin.de'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2013, 'phase': {}, 'to': 2022},
#                'institution': {},
#                'membership-type': 'current'},
#               {'dates': {'from': 2013, 'phase': {}, 'to': 2022},
#                'institution': {},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'acronyms': 'ISSI',
#                                'cmip-acronym': 'ISSI',
#                                'established': 1995,
#                                'location': {'city': 'Bern',
#                                             'country': ['Switzerland', 'CH'],
#                                             'lat': 46.952897,
#                                             'lon': 46.952897},
#                                'name': 'International Space Science Institute',
#                                'ror': '01xm30661',
#                                'type': 'Nonprofit',
#                                'url': 'http://www.issibern.ch/'},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'acronyms': 'KIT',
#                                'aliases': ['Karlsruhe Institute of Technology '
#                                            '- The Research University in the '
#                                            'Helmholtz Association',
#                                            'Das Karlsruher Institut für '
#                                            'Technologie (KIT) – Die '
#                                            'Forschungsuniversität in der '
#                                            'Helmholtz-Gemeinschaft'],
#                                'cmip-acronym': 'KIT',
#                                'established': 2009,
#                                'location': {'city': 'Karlsruhe',
#                                             'country': ['Germany', 'DE'],
#                                             'lat': 49.00937,
#                                             'lon': 49.00937},
#                                'name': 'Karlsruhe Institute of Technology',
#                                'ror': '04t3en479',
#                                'type': 'Education',
#                                'url': 'http://www.kit.edu/english/'},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'acronyms': 'LPC2E',
#                                'cmip-acronym': 'LPC2E',
#                                'established': 2012,
#                                'location': {'city': 'Orléans',
#                                             'country': ['France', 'FR'],
#                                             'lat': 47.90289,
#                                             'lon': 47.90289},
#                                'name': 'Laboratoire de Physique et Chimie de '
#                                        'l’Environnement et de l’Espace',
#                                'ror': '049k66y27',
#                                'type': 'Facility',
#                                'url': 'https://www.lpc2e.cnrs.fr'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2013, 'phase': {}, 'to': 2022},
#                'institution': {'aliases': 'Meteorological Office',
#                                'cmip-acronym': 'MOHC',
#                                'established': 1854,
#                                'location': {'city': 'Exeter',
#                                             'country': ['United Kingdom', 'GB'],
#                                             'lat': 50.7236,
#                                             'lon': 50.7236},
#                                'name': 'Met Office',
#                                'ror': '01ch2yn61',
#                                'type': 'Government',
#                                'url': 'http://www.metoffice.gov.uk/'},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'acronyms': 'MPS',
#                                'cmip-acronym': 'MPS',
#                                'established': 1934,
#                                'location': {'city': 'Göttingen',
#                                             'country': ['Germany', 'DE'],
#                                             'lat': 51.561218,
#                                             'lon': 51.561218},
#                                'name': 'Max Planck Institute for Solar System '
#                                        'Research',
#                                'ror': '02j6gm739',
#                                'type': 'Facility',
#                                'url': 'http://www.mps.mpg.de/en'},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'acronyms': 'NCAR',
#                                'cmip-acronym': 'NCAR',
#                                'established': 1930,
#                                'location': {'city': 'Boulder',
#                                             'country': ['United States', 'US'],
#                                             'lat': 40.01499,
#                                             'lon': 40.01499},
#                                'name': 'National Center for Atmospheric '
#                                        'Research',
#                                'ror': '05cvfcr44',
#                                'type': 'Facility',
#                                'url': 'https://ncar.ucar.edu/'},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'acronyms': 'PMOD',
#                                'cmip-acronym': 'PMOD',
#                                'established': 1907,
#                                'location': {'city': 'Davos',
#                                             'country': ['Switzerland', 'CH'],
#                                             'lat': 46.8133161,
#                                             'lon': 46.8133161},
#                                'name': 'Physikalisch-Meteorologisches '
#                                        'Observatorium Davos',
#                                'ror': '02gtrqv93',
#                                'type': 'Facility',
#                                'url': 'https://www.pmodwrc.ch/'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2025, 'phase': {}, 'to': '-'},
#                'institution': {'acronyms': 'UiB',
#                                'cmip-acronym': 'UoBergen',
#                                'established': 1946,
#                                'location': {'city': 'Bergen',
#                                             'country': ['Norway', 'NO'],
#                                             'lat': 60.39299,
#                                             'lon': 60.39299},
#                                'name': 'University of Bergen',
#                                'ror': '03zga2b32',
#                                'type': 'Education',
#                                'url': 'http://www.uib.no/'},
#                'institution:@tyconsortia:pe': 'member',
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'cmip-acronym': 'UoLeeds',
#                                'established': 1904,
#                                'location': {'city': 'Leeds',
#                                             'country': ['United Kingdom', 'GB'],
#                                             'lat': 53.79648,
#                                             'lon': 53.79648},
#                                'name': 'University of Leeds',
#                                'ror': '024mrxd33',
#                                'type': 'Education',
#                                'url': 'http://www.leeds.ac.uk/'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2013, 'phase': {}, 'to': 2022},
#                'institution': {'acronyms': 'UdeM',
#                                'cmip-acronym': 'UoMontreal',
#                                'established': 1878,
#                                'location': {'city': 'Montreal',
#                                             'country': ['Canada', 'CA'],
#                                             'lat': 45.50884,
#                                             'lon': 45.50884},
#                                'name': 'Université de Montréal',
#                                'ror': '0161xgx34',
#                                'type': 'Education',
#                                'url': 'http://www.umontreal.ca/english/'},
#                'membership-type': 'current'},
#               {'dates': [{'from': 2013, 'phase': {}, 'to': 2022},
#                          {'from': 2025, 'phase': {}, 'to': '-'}],
#                'institution': {'cmip-acronym': 'UoOtago',
#                                'established': 1869,
#                                'location': {'city': 'Dunedin',
#                                             'country': ['New Zealand', 'NZ'],
#                                             'lat': -45.87416,
#                                             'lon': -45.87416},
#                                'name': 'University of Otago',
#                                'ror': '01jmxt844',
#                                'type': 'Education',
#                                'url': 'http://www.otago.ac.nz/'},
#                'membership-type': 'current'},
#               {'dates': {'from': 2025, 'phase': {}, 'to': '-'},
#                'institution': {'cmip-acronym': 'UoOulu',
#                                'established': 1958,
#                                'location': {'city': 'Oulu',
#                                             'country': ['Finland', 'FI'],
#                                             'lat': 65.01236,
#                                             'lon': 65.01236},
#                                'name': 'University of Oulu',
#                                'ror': '03yj89h83',
#                                'type': 'Education',
#                                'url': 'http://www.oulu.fi/english/'},
#                'membership-type': 'current'}],
#   'name': 'SOLARIS HEPPA Consortium',
#   'url': 'https://solarisheppa.geomar.de'},
#  {'acronyms': 'AER',
#   'cmip-acronym': 'AER',
#   'established': 1977,
#   'location': {'city': 'Lexington',
#                'country': ['United States', 'US'],
#                'lat': 42.539472,
#                'lon': -71.256946},
#   'name': 'Atmospheric and Environmental Research',
#   'ror': '04cg70g73',
#   'type': 'Facility',
#   'url': 'http://www.aer.com/'},
#  {'cmip-acronym': 'AoR',
#   'established': 1938,
#   'location': {'city': 'Rome',
#                'country': ['Italy', 'IT'],
#                'lat': 41.921669,
#                'lon': 41.921669},
#   'name': 'Astronomical Observatory of Rome',
#   'ror': '02hnp4676',
#   'type': 'Facility',
#   'url': 'http://web.oa-roma.inaf.it/'},
#  {'acronyms': 'RCEC',
#   'cmip-acronym': 'AS-RCEC',
#   'established': 0,
#   'location': {'city': 'Taipei',
#                'country': ['Taiwan', 'TW'],
#                'lat': 25.040712,
#                'lon': 121.614171},
#   'name': 'Research Center for Environmental Changes, Academia Sinica',
#   'ror': '050qpg053',
#   'type': 'Facility',
#   'url': 'http://www.rcec.sinica.edu.tw/'},
#  {'aliases': 'Aristotelian University',
#   'cmip-acronym': 'AUoT',
#   'established': 1925,
#   'location': {'city': 'Thessaloniki',
#                'country': ['Greece', 'GR'],
#                'lat': 40.64361,
#                'lon': 40.64361},
#   'name': 'Aristotle University of Thessaloniki',
#   'ror': '02j61yw88',
#   'type': 'Education',
#   'url': 'https://www.auth.gr/en'},
#  {'acronyms': 'AWI',
#   'cmip-acronym': 'AWI',
#   'established': 1980,
#   'location': {'city': 'Bremerhaven',
#                'country': ['Germany', 'DE'],
#                'lat': 53.53615,
#                'lon': 8.59298},
#   'name': 'Alfred Wegener Institute for Polar and Marine Research',
#   'ror': '032e6b942',
#   'type': 'Facility',
#   'url': 'https://www.awi.de'},
#  {'acronyms': 'BAS',
#   'cmip-acronym': 'BAS',
#   'established': 1962,
#   'location': {'city': 'Cambridge',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 52.212965,
#                'lon': 52.212965},
#   'name': 'British Antarctic Survey',
#   'ror': '01rhff309',
#   'type': 'Government',
#   'url': 'https://www.bas.ac.uk/'},
#  {'cmip-acronym': 'BCC',
#   'established': 2008,
#   'location': {'city': 'Beijing',
#                'country': ['China', 'CN'],
#                'lat': 39.950128,
#                'lon': 116.383679},
#   'name': 'Beijing Biocytogen (China)',
#   'ror': '01spyyb53',
#   'type': 'Company',
#   'url': 'http://www.bbctg.com.cn/'},
#  {'acronyms': 'CAMS',
#   'cmip-acronym': 'CAMS',
#   'established': 1978,
#   'location': {'city': 'Beijing',
#                'country': ['China', 'CN'],
#                'lat': 39.9075,
#                'lon': 116.39723},
#   'name': 'Chinese Academy of Meteorological Sciences',
#   'ror': '034b53w38',
#   'type': 'Facility',
#   'url': 'http://www.camscma.cn/en.html'},
#  {'acronyms': 'CAS',
#   'cmip-acronym': 'CAS',
#   'established': 1949,
#   'location': {'city': 'Beijing',
#                'country': ['China', 'CN'],
#                'lat': 39.9075,
#                'lon': 116.39723},
#   'name': 'Chinese Academy of Sciences',
#   'ror': '034t30j35',
#   'type': 'Government',
#   'url': 'http://english.cas.cn/'},
#  {'acronyms': 'ECCC',
#   'cmip-acronym': 'CCCma',
#   'established': 1971,
#   'location': {'city': 'Gatineau',
#                'country': ['Canada', 'CA'],
#                'lat': 45.425373,
#                'lon': -75.699862},
#   'name': 'Environment and Climate Change Canada',
#   'ror': '026ny0e17',
#   'type': 'Government',
#   'url': 'https://www.canada.ca/en/environment-climate-change.html'},
#  {'acronyms': 'IITM',
#   'cmip-acronym': 'CCCR-IITM',
#   'established': 1962,
#   'location': {'city': 'Pune',
#                'country': ['India', 'IN'],
#                'lat': 18.51957,
#                'lon': 73.85535},
#   'name': 'Indian Institute of Tropical Meteorology',
#   'ror': '03jf2m686',
#   'type': 'Facility',
#   'url': 'http://www.tropmet.res.in/'},
#  {'acronyms': 'CEDA',
#   'cmip-acronym': 'CEDA',
#   'established': 2005,
#   'location': {'city': 'Harwell',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 53.41667,
#                'lon': -0.96667},
#   'name': 'Centre for Environmental Data Analysis',
#   'ror': '04j4kad11',
#   'type': 'Government',
#   'url': 'https://www.ceda.ac.uk/'},
#  {'acronyms': 'CMCC',
#   'cmip-acronym': 'CMCC',
#   'established': 2005,
#   'location': {'city': 'Lecce',
#                'country': ['Italy', 'IT'],
#                'lat': 40.33942,
#                'lon': 18.086602},
#   'name': 'Euro-Mediterranean Center for Climate Change',
#   'ror': '01tf11a61',
#   'type': 'Nonprofit',
#   'url': 'http://www.cmcc.it/'},
#  {'acronyms': 'CNES',
#   'cmip-acronym': 'CNES',
#   'established': 1961,
#   'location': {'city': 'Paris',
#                'country': ['France', 'FR'],
#                'lat': 48.85341,
#                'lon': 2.3488},
#   'name': "Centre National d'Études Spatiales",
#   'ror': '04h1h0y33',
#   'type': 'Government',
#   'url': 'https://www.cnes.fr'},
#  {'acronyms': 'CSIRO',
#   'cmip-acronym': 'CSIRO',
#   'established': 1926,
#   'location': {'city': 'Canberra',
#                'country': ['Australia', 'AU'],
#                'lat': -35.28346,
#                'lon': 149.12807},
#   'name': 'Commonwealth Scientific and Industrial Research Organisation',
#   'ror': '03qn8fb07',
#   'type': 'Government',
#   'url': 'http://www.csiro.au/'},
#  {'acronyms': 'DKRZ',
#   'cmip-acronym': 'DKRZ',
#   'established': 1987,
#   'location': {'city': 'Hamburg',
#                'country': ['Germany', 'DE'],
#                'lat': 53.55073,
#                'lon': 9.99302},
#   'name': 'German Climate Computing Centre',
#   'ror': '03ztgj037',
#   'type': 'Facility',
#   'url': 'https://www.dkrz.de/'},
#  {'acronyms': 'DWD',
#   'cmip-acronym': 'DWD',
#   'established': 1952,
#   'location': {'city': 'Offenbach',
#                'country': ['Germany', 'DE'],
#                'lat': 50.103322,
#                'lon': 8.747606},
#   'name': 'German Meteorological Service',
#   'ror': '02nrqs528',
#   'type': 'Facility',
#   'url': 'http://www.dwd.de/'},
#  {'acronyms': 'EAWAG',
#   'cmip-acronym': 'EAWAG',
#   'established': 1936,
#   'location': {'city': 'Dübendorf',
#                'country': ['Switzerland', 'CH'],
#                'lat': 47.39724,
#                'lon': 47.39724},
#   'name': 'Swiss Federal Institute of Aquatic Science and Technology',
#   'ror': '00pc48d59',
#   'type': 'Facility',
#   'url': 'http://www.eawag.ch/en/'},
#  {'acronyms': 'ECMWF',
#   'cmip-acronym': 'ECMWF',
#   'established': 1975,
#   'location': {'city': 'Reading',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 51.45625,
#                'lon': -0.97113},
#   'name': 'European Centre for Medium-Range Weather Forecasts',
#   'ror': '014w0fd65',
#   'type': 'Other',
#   'url': 'http://www.ecmwf.int/'},
#  {'acronyms': 'INCOIS',
#   'cmip-acronym': 'ESSO',
#   'established': 1999,
#   'location': {'city': 'Hyderabad',
#                'country': ['India', 'IN'],
#                'lat': 17.528234,
#                'lon': 78.400195},
#   'name': 'Indian National Centre for Ocean Information Services',
#   'ror': '04xbqmj23',
#   'type': 'Government',
#   'url': 'http://www.incois.gov.in/portal/index.jsp'},
#  {'acronyms': 'FMI',
#   'cmip-acronym': 'FMI',
#   'established': 1838,
#   'location': {'city': 'Helsinki',
#                'country': ['Finland', 'FI'],
#                'lat': 60.16952,
#                'lon': 60.16952},
#   'name': 'Finnish Meteorological Institute',
#   'ror': '05hppb561',
#   'type': 'Government',
#   'url': 'http://en.ilmatieteenlaitos.fi/'},
#  {'acronyms': 'FU',
#   'aliases': ['FU Berlin', 'Free University of Berlin'],
#   'cmip-acronym': 'FUBerlin',
#   'established': 1948,
#   'location': {'city': 'Berlin',
#                'country': ['Germany', 'DE'],
#                'lat': 52.52437,
#                'lon': 52.52437},
#   'name': 'Freie Universität Berlin',
#   'ror': '046ak2485',
#   'type': 'Education',
#   'url': 'https://www.fu-berlin.de'},
#  {'aliases': ['Swiss Federal Institute of Technology in Zurich',
#               'Eidgenössische Technische Hochschule Zürich',
#               'École Polytechnique Fédérale de Zurich',
#               'Politecnico Federale di Zurigo'],
#   'cmip-acronym': 'IACETH',
#   'established': 1855,
#   'location': {'city': 'Zurich',
#                'country': ['Switzerland', 'CH'],
#                'lat': 47.36667,
#                'lon': 8.55},
#   'name': 'ETH Zurich',
#   'ror': '05a28rw58',
#   'type': 'Education',
#   'url': 'https://ethz.ch'},
#  {'acronyms': 'IFM-GEOMAR',
#   'aliases': 'Leibniz Institute of Marine Sciences',
#   'cmip-acronym': 'IFM-GEOMAR',
#   'established': 2004,
#   'location': {'city': 'Kiel',
#                'country': ['Germany', 'DE'],
#                'lat': 54.327138,
#                'lon': 10.180141},
#   'name': 'GEOMAR Helmholtz Centre for Ocean Research Kiel',
#   'ror': '02h2x0161',
#   'type': 'Facility',
#   'url': 'http://www.geomar.de/en/'},
#  {'cmip-acronym': 'ImperialCollege',
#   'established': 1907,
#   'location': {'city': 'London',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 51.4986,
#                'lon': -0.175478},
#   'name': 'Imperial College London',
#   'ror': '041kmwe10',
#   'type': 'Education',
#   'url': 'http://www.imperial.ac.uk/'},
#  {'acronyms': 'INM RAS',
#   'cmip-acronym': 'INM',
#   'established': 1980,
#   'location': {'city': 'Moscow',
#                'country': ['Russia', 'RU'],
#                'lat': 55.762997,
#                'lon': 37.625605},
#   'name': 'Institute of Numerical Mathematics',
#   'ror': '00520ey40',
#   'type': 'Facility',
#   'url': 'http://www.inm.ras.ru/inm_en_ver/index.htm'},
#  {'acronyms': 'IPSL',
#   'cmip-acronym': 'IPSL',
#   'established': 1991,
#   'location': {'city': 'Paris',
#                'country': ['France', 'FR'],
#                'lat': 48.855675,
#                'lon': 2.332105},
#   'name': 'Institut Pierre-Simon Laplace',
#   'ror': '02haar591',
#   'type': 'Facility',
#   'url': 'https://www.ipsl.fr/en/'},
#  {'acronyms': 'ISSI',
#   'cmip-acronym': 'ISSI',
#   'established': 1995,
#   'location': {'city': 'Bern',
#                'country': ['Switzerland', 'CH'],
#                'lat': 46.952897,
#                'lon': 46.952897},
#   'name': 'International Space Science Institute',
#   'ror': '01xm30661',
#   'type': 'Nonprofit',
#   'url': 'http://www.issibern.ch/'},
#  {'acronyms': 'JAXA',
#   'aliases': ['Dokuritsu-gyōsei-hōjin Uchū Kōkū Kenkyū Kaihatsu Kikō',
#               'Independent Administrative Institution on Aerospace Research '
#               'and Development'],
#   'cmip-acronym': 'JAXA',
#   'established': 2003,
#   'location': {'city': 'Tokyo',
#                'country': ['Japan', 'JP'],
#                'lat': 35.680834,
#                'lon': 139.558269},
#   'name': 'Japan Aerospace Exploration Agency',
#   'ror': '059yhyy33',
#   'type': 'Facility',
#   'url': 'http://global.jaxa.jp/'},
#  {'acronyms': 'KIOST',
#   'aliases': 'Korean Ocean Research and Development Institute',
#   'cmip-acronym': 'KIOST',
#   'established': 1973,
#   'location': {'city': 'Busan',
#                'country': ['South Korea', 'KR'],
#                'lat': 35.10168,
#                'lon': 129.03004},
#   'name': 'Korea Institute of Ocean Science and Technology',
#   'ror': '032m55064',
#   'type': 'Facility',
#   'url': 'http://eng.kiost.ac/'},
#  {'acronyms': 'KIT',
#   'aliases': ['Karlsruhe Institute of Technology - The Research University in '
#               'the Helmholtz Association',
#               'Das Karlsruher Institut für Technologie (KIT) – Die '
#               'Forschungsuniversität in der Helmholtz-Gemeinschaft'],
#   'cmip-acronym': 'KIT',
#   'established': 2009,
#   'location': {'city': 'Karlsruhe',
#                'country': ['Germany', 'DE'],
#                'lat': 49.00937,
#                'lon': 49.00937},
#   'name': 'Karlsruhe Institute of Technology',
#   'ror': '04t3en479',
#   'type': 'Education',
#   'url': 'http://www.kit.edu/english/'},
#  {'acronyms': ['LLNL', 'LLL'],
#   'aliases': ['United States Department of Energy National Nuclear Security '
#               'Administration Lawrence Livermore National Laboratory',
#               'U.S. Department of Energy National Nuclear Security '
#               'Administration Los Alamos National Laboratory',
#               'United States Department of Energy Los Alamos National '
#               'Laboratory',
#               'U.S. Department of Energy Los Alamos National Laboratory'],
#   'cmip-acronym': 'LLNL',
#   'established': 1952,
#   'location': {'city': 'Livermore',
#                'country': ['United States', 'US'],
#                'lat': 37.68187,
#                'lon': -121.76801},
#   'name': 'Lawrence Livermore National Laboratory',
#   'ror': '041nk4h53',
#   'type': 'Facility',
#   'url': 'https://www.llnl.gov/'},
#  {'acronyms': 'LPC2E',
#   'cmip-acronym': 'LPC2E',
#   'established': 2012,
#   'location': {'city': 'Orléans',
#                'country': ['France', 'FR'],
#                'lat': 47.90289,
#                'lon': 47.90289},
#   'name': 'Laboratoire de Physique et Chimie de l’Environnement et de l’Espace',
#   'ror': '049k66y27',
#   'type': 'Facility',
#   'url': 'https://www.lpc2e.cnrs.fr'},
#  {'aliases': 'Meteorological Office',
#   'cmip-acronym': 'MOHC',
#   'established': 1854,
#   'location': {'city': 'Exeter',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 50.7236,
#                'lon': 50.7236},
#   'name': 'Met Office',
#   'ror': '01ch2yn61',
#   'type': 'Government',
#   'url': 'http://www.metoffice.gov.uk/'},
#  {'cmip-acronym': 'MPI-B',
#   'established': 1997,
#   'location': {'city': 'Jena',
#                'country': ['Germany', 'DE'],
#                'lat': 50.910556,
#                'lon': 11.567222},
#   'name': 'Max Planck Institute for Biogeochemistry',
#   'ror': '051yxp643',
#   'type': 'Facility',
#   'url': 'http://www.bgc-jena.mpg.de/'},
#  {'acronyms': 'MPI-M',
#   'cmip-acronym': 'MPI-M',
#   'established': 1975,
#   'location': {'city': 'Hamburg',
#                'country': ['Germany', 'DE'],
#                'lat': 53.567794,
#                'lon': 9.975468},
#   'name': 'Max Planck Institute for Meteorology',
#   'ror': '05esem239',
#   'type': 'Facility',
#   'url': 'http://www.mpimet.mpg.de/en/home.html'},
#  {'acronyms': 'MPS',
#   'cmip-acronym': 'MPS',
#   'established': 1934,
#   'location': {'city': 'Göttingen',
#                'country': ['Germany', 'DE'],
#                'lat': 51.561218,
#                'lon': 51.561218},
#   'name': 'Max Planck Institute for Solar System Research',
#   'ror': '02j6gm739',
#   'type': 'Facility',
#   'url': 'http://www.mps.mpg.de/en'},
#  {'acronyms': 'JMA',
#   'aliases': 'Kishō-chō',
#   'cmip-acronym': 'MRI',
#   'established': 1956,
#   'location': {'city': 'Tokyo',
#                'country': ['Japan', 'JP'],
#                'lat': 35.6895,
#                'lon': 139.69171},
#   'name': 'Japan Meteorological Agency',
#   'ror': '02772kk97',
#   'type': 'Other',
#   'url': 'http://www.jma.go.jp/jma/indexe.html'},
#  {'acronyms': 'GISS',
#   'cmip-acronym': 'NASA-GISS',
#   'established': 1961,
#   'location': {'city': 'New York',
#                'country': ['United States', 'US'],
#                'lat': 40.71427,
#                'lon': -74.00597},
#   'name': 'Goddard Institute for Space Studies',
#   'ror': '01cyfxe35',
#   'type': 'Facility',
#   'url': 'http://www.giss.nasa.gov/'},
#  {'acronyms': 'GSFC',
#   'cmip-acronym': 'NASA-GSFC',
#   'established': 1959,
#   'location': {'city': 'Greenbelt',
#                'country': ['United States', 'US'],
#                'lat': 39.00455,
#                'lon': -76.87553},
#   'name': 'Goddard Space Flight Center',
#   'ror': '0171mag52',
#   'type': 'Facility',
#   'url': 'https://www.nasa.gov/centers/goddard/home/index.html'},
#  {'acronyms': 'JPL',
#   'aliases': ['Jet Propulsion Lab',
#               'Jet Propulsion Laboratory, California Institute of Technology'],
#   'cmip-acronym': 'NASA-JPL',
#   'established': 1936,
#   'location': {'city': 'La Cañada Flintridge',
#                'country': ['United States', 'US'],
#                'lat': 34.19917,
#                'lon': -118.18785},
#   'name': 'Jet Propulsion Laboratory',
#   'ror': '027k65916',
#   'type': 'Facility',
#   'url': 'http://www.jpl.nasa.gov/'},
#  {'acronyms': 'LaRC',
#   'cmip-acronym': 'NASA-LaRC',
#   'established': 1917,
#   'location': {'city': 'Hampton',
#                'country': ['United States', 'US'],
#                'lat': 37.02987,
#                'lon': -76.34522},
#   'name': 'Langley Research Center',
#   'ror': '0399mhs52',
#   'type': 'Facility',
#   'url': 'http://www.nasa.gov/langley'},
#  {'acronyms': 'NCAR',
#   'cmip-acronym': 'NCAR',
#   'established': 1930,
#   'location': {'city': 'Boulder',
#                'country': ['United States', 'US'],
#                'lat': 40.01499,
#                'lon': 40.01499},
#   'name': 'National Center for Atmospheric Research',
#   'ror': '05cvfcr44',
#   'type': 'Facility',
#   'url': 'https://ncar.ucar.edu/'},
#  {'cmip-acronym': 'NCAS',
#   'established': 1997,
#   'location': {'city': 'Islamabad',
#                'country': ['Pakistan', 'PK'],
#                'lat': 33.72148,
#                'lon': 73.04329},
#   'name': 'Uks',
#   'ror': '03q36cn05',
#   'type': 'Facility',
#   'url': 'http://www.uksresearch.com/'},
#  {'acronyms': 'NERC',
#   'cmip-acronym': 'NERC',
#   'established': 1965,
#   'location': {'city': 'Swindon',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 51.55797,
#                'lon': -1.78116},
#   'name': 'Natural Environment Research Council',
#   'ror': '02b5d8509',
#   'type': 'Government',
#   'url': 'https://www.ukri.org/councils/nerc/'},
#  {'acronyms': 'NIWA',
#   'aliases': 'Taihoro Nukurangi',
#   'cmip-acronym': 'NIWA',
#   'established': 1992,
#   'location': {'city': 'Auckland',
#                'country': ['New Zealand', 'NZ'],
#                'lat': -36.84403,
#                'lon': 174.76172},
#   'name': 'National Institute of Water and Atmospheric Research',
#   'ror': '04hxcaz34',
#   'type': 'Facility',
#   'url': 'https://www.niwa.co.nz/'},
#  {'acronyms': ['NCEI', 'NOAA NCEI'],
#   'aliases': ['National Climatic Data Center',
#               'United States National Environmental Satellites, Data, and '
#               'Information Service National Centers for Environmental '
#               'Information',
#               'United States National Centers for Environmental Information',
#               'U.S. National Centers for Environmental Information',
#               'National Centers for Environmental Information'],
#   'cmip-acronym': 'NOAA-NCEI',
#   'established': 1934,
#   'location': {'city': 'Asheville',
#                'country': ['United States', 'US'],
#                'lat': 35.60095,
#                'lon': -82.55402},
#   'name': 'NOAA National Centers for Environmental Information',
#   'ror': '04r0wrp59',
#   'type': 'Government',
#   'url': 'https://www.ncei.noaa.gov'},
#  {'acronyms': 'NTU',
#   'cmip-acronym': 'NTU',
#   'established': 1928,
#   'location': {'city': 'Taipei',
#                'country': ['Taiwan', 'TW'],
#                'lat': 25.016,
#                'lon': 121.536},
#   'name': 'National Taiwan University',
#   'ror': '05bqach95',
#   'type': 'Education',
#   'url': 'http://www.ntu.edu.tw/english/'},
#  {'acronyms': ['NU', 'NJU '],
#   'aliases': 'Nanking University',
#   'cmip-acronym': 'NUIST',
#   'established': 1902,
#   'location': {'city': 'Nanjing',
#                'country': ['China', 'CN'],
#                'lat': 32.056111,
#                'lon': 118.775},
#   'name': 'Nanjing University',
#   'ror': '01rxvg760',
#   'type': 'Education',
#   'url': 'http://www.nju.edu.cn/english/'},
#  {'acronyms': 'OSU',
#   'cmip-acronym': 'OSU',
#   'established': 1868,
#   'location': {'city': 'Corvallis',
#                'country': ['United States', 'US'],
#                'lat': 44.56457,
#                'lon': -123.26204},
#   'name': 'Oregon State University',
#   'ror': '00ysfqy60',
#   'type': 'Education',
#   'url': 'http://oregonstate.edu/'},
#  {'acronyms': ['LLNL', 'LLL'],
#   'aliases': ['United States Department of Energy National Nuclear Security '
#               'Administration Lawrence Livermore National Laboratory',
#               'U.S. Department of Energy National Nuclear Security '
#               'Administration Los Alamos National Laboratory',
#               'United States Department of Energy Los Alamos National '
#               'Laboratory',
#               'U.S. Department of Energy Los Alamos National Laboratory'],
#   'cmip-acronym': 'PCMDI',
#   'established': 1952,
#   'location': {'city': 'Livermore',
#                'country': ['United States', 'US'],
#                'lat': 37.68187,
#                'lon': -121.76801},
#   'name': 'Lawrence Livermore National Laboratory',
#   'ror': '041nk4h53',
#   'type': 'Facility',
#   'url': 'https://www.llnl.gov/'},
#  {'acronyms': 'PMOD',
#   'cmip-acronym': 'PMOD',
#   'established': 1907,
#   'location': {'city': 'Davos',
#                'country': ['Switzerland', 'CH'],
#                'lat': 46.8133161,
#                'lon': 46.8133161},
#   'name': 'Physikalisch-Meteorologisches Observatorium Davos',
#   'ror': '02gtrqv93',
#   'type': 'Facility',
#   'url': 'https://www.pmodwrc.ch/'},
#  {'acronyms': 'JGCRI',
#   'cmip-acronym': 'PNNL-JGCRI',
#   'established': 2001,
#   'location': {'city': 'Riverdale Park',
#                'country': ['United States', 'US'],
#                'lat': 38.971106,
#                'lon': -76.9217851},
#   'name': 'Joint Global Change Research Institute',
#   'ror': '058cmd703',
#   'type': 'Facility',
#   'url': 'http://www.globalchange.umd.edu/'},
#  {'acronyms': 'PNNL',
#   'cmip-acronym': 'PNNL-WACCEM',
#   'established': 1965,
#   'location': {'city': 'Richland',
#                'country': ['United States', 'US'],
#                'lat': 46.28569,
#                'lon': -119.28446},
#   'name': 'Pacific Northwest National Laboratory',
#   'ror': '05h992307',
#   'type': 'Facility',
#   'url': 'http://www.pnnl.gov/'},
#  {'acronyms': 'RSS',
#   'cmip-acronym': 'RSS',
#   'established': 1974,
#   'location': {'city': 'Santa Rosa',
#                'country': ['United States', 'US'],
#                'lat': 38.443733,
#                'lon': -122.717185},
#   'name': 'Remote Sensing Systems (United States)',
#   'ror': '01vp8h012',
#   'type': 'Company',
#   'url': 'http://www.remss.com/'},
#  {'acronyms': 'SNU',
#   'aliases': 'Seoul Daehakgyo',
#   'cmip-acronym': 'SNU',
#   'established': 1946,
#   'location': {'city': 'Seoul',
#                'country': ['South Korea', 'KR'],
#                'lat': 37.460155,
#                'lon': 126.951894},
#   'name': 'Seoul National University',
#   'ror': '04h9pn542',
#   'type': 'Education',
#   'url': 'http://www.snu.ac.kr/index.html'},
#  {'acronyms': 'THU',
#   'cmip-acronym': 'THU',
#   'established': 1911,
#   'location': {'city': 'Beijing',
#                'country': ['China', 'CN'],
#                'lat': 39.999585,
#                'lon': 116.325414},
#   'name': 'Tsinghua University',
#   'ror': '03cve4549',
#   'type': 'Education',
#   'url': 'http://www.tsinghua.edu.cn/publish/newthuen/'},
#  {'acronyms': 'UA',
#   'cmip-acronym': 'UA',
#   'established': 1885,
#   'location': {'city': 'Tucson',
#                'country': ['United States', 'US'],
#                'lat': 32.22174,
#                'lon': -110.92648},
#   'name': 'University of Arizona',
#   'ror': '03m2x1q45',
#   'type': 'Education',
#   'url': 'http://www.arizona.edu/'},
#  {'acronyms': 'UCI',
#   'aliases': 'UC Irvine',
#   'cmip-acronym': 'UCI',
#   'established': 1965,
#   'location': {'city': 'Irvine',
#                'country': ['United States', 'US'],
#                'lat': 33.64535,
#                'lon': -117.842642},
#   'name': 'University of California, Irvine',
#   'ror': '04gyf1771',
#   'type': 'Education',
#   'url': 'http://uci.edu/'},
#  {'acronyms': 'CU',
#   'cmip-acronym': 'UColorado',
#   'established': 1876,
#   'location': {'city': 'Boulder',
#                'country': ['United States', 'US'],
#                'lat': 40.01499,
#                'lon': -105.27055},
#   'name': 'University of Colorado System',
#   'ror': '00jc20583',
#   'type': 'Education',
#   'url': 'http://www.cu.edu/'},
#  {'acronyms': 'UCSB',
#   'aliases': 'UC Santa Barbara',
#   'cmip-acronym': 'UCSB',
#   'established': 1891,
#   'location': {'city': 'Santa Barbara',
#                'country': ['United States', 'US'],
#                'lat': 34.42083,
#                'lon': -119.69819},
#   'name': 'University of California, Santa Barbara',
#   'ror': '02t274463',
#   'type': 'Education',
#   'url': 'http://www.ucsb.edu/'},
#  {'acronyms': 'UHH',
#   'aliases': 'University of Hamburg',
#   'cmip-acronym': 'UHH',
#   'established': 1919,
#   'location': {'city': 'Hamburg',
#                'country': ['Germany', 'DE'],
#                'lat': 53.55073,
#                'lon': 9.99302},
#   'name': 'Universität Hamburg',
#   'ror': '00g30e956',
#   'type': 'Education',
#   'url': 'http://www.uni-hamburg.de'},
#  {'acronyms': 'UiB',
#   'cmip-acronym': 'UoBergen',
#   'established': 1946,
#   'location': {'city': 'Bergen',
#                'country': ['Norway', 'NO'],
#                'lat': 60.39299,
#                'lon': 60.39299},
#   'name': 'University of Bergen',
#   'ror': '03zga2b32',
#   'type': 'Education',
#   'url': 'http://www.uib.no/'},
#  {'acronyms': 'UMD',
#   'cmip-acronym': 'UofMD',
#   'established': 1856,
#   'location': {'city': 'College Park',
#                'country': ['United States', 'US'],
#                'lat': 38.98067,
#                'lon': -76.93692},
#   'name': 'University of Maryland, College Park',
#   'ror': '047s2c258',
#   'type': 'Education',
#   'url': 'http://www.umd.edu/'},
#  {'cmip-acronym': 'UoLeeds',
#   'established': 1904,
#   'location': {'city': 'Leeds',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 53.79648,
#                'lon': 53.79648},
#   'name': 'University of Leeds',
#   'ror': '024mrxd33',
#   'type': 'Education',
#   'url': 'http://www.leeds.ac.uk/'},
#  {'aliases': 'Melbourne University',
#   'cmip-acronym': 'UoM',
#   'established': 1853,
#   'location': {'city': 'Melbourne',
#                'country': ['Australia', 'AU'],
#                'lat': -37.814,
#                'lon': 144.96332},
#   'name': 'University of Melbourne',
#   'ror': '01ej9dk98',
#   'type': 'Education',
#   'url': 'http://www.unimelb.edu.au/'},
#  {'acronyms': 'UdeM',
#   'cmip-acronym': 'UoMontreal',
#   'established': 1878,
#   'location': {'city': 'Montreal',
#                'country': ['Canada', 'CA'],
#                'lat': 45.50884,
#                'lon': 45.50884},
#   'name': 'Université de Montréal',
#   'ror': '0161xgx34',
#   'type': 'Education',
#   'url': 'http://www.umontreal.ca/english/'},
#  {'cmip-acronym': 'UoOtago',
#   'established': 1869,
#   'location': {'city': 'Dunedin',
#                'country': ['New Zealand', 'NZ'],
#                'lat': -45.87416,
#                'lon': -45.87416},
#   'name': 'University of Otago',
#   'ror': '01jmxt844',
#   'type': 'Education',
#   'url': 'http://www.otago.ac.nz/'},
#  {'cmip-acronym': 'UoOulu',
#   'established': 1958,
#   'location': {'city': 'Oulu',
#                'country': ['Finland', 'FI'],
#                'lat': 65.01236,
#                'lon': 65.01236},
#   'name': 'University of Oulu',
#   'ror': '03yj89h83',
#   'type': 'Education',
#   'url': 'http://www.oulu.fi/english/'},
#  {'cmip-acronym': 'UReading',
#   'established': 1926,
#   'location': {'city': 'Reading',
#                'country': ['United Kingdom', 'GB'],
#                'lat': 51.440832,
#                'lon': -0.942503},
#   'name': 'University of Reading',
#   'ror': '05v62cm79',
#   'type': 'Education',
#   'url': 'http://www.reading.ac.uk/'},
#  {'acronyms': 'UW',
#   'cmip-acronym': 'UW',
#   'established': 1861,
#   'location': {'city': 'Seattle',
#                'country': ['United States', 'US'],
#                'lat': 47.60621,
#                'lon': -122.33207},
#   'name': 'University of Washington',
#   'ror': '00cvxb145',
#   'type': 'Education',
#   'url': 'http://www.washington.edu/'},
#  {'acronyms': 'VU',
#   'aliases': 'VU Amsterdam',
#   'cmip-acronym': 'VUA',
#   'established': 1880,
#   'location': {'city': 'Amsterdam',
#                'country': ['Netherlands', 'NL'],
#                'lat': 52.37403,
#                'lon': 4.88969},
#   'name': 'Vrije Universiteit Amsterdam',
#   'ror': '008xxew50',
#   'type': 'Education',
#   'url': 'https://vu.nl/'}]

# %% [markdown]
# ## Using python to massage the data
# Now we can view the keysm and edit items as needed.

# %%
dict([[i['cmip-acronym'],f"{i['name']}: {i['url']}"] for i in data.data])
# Out:
# {'MIROC': 'MIROC Consortium: ',
#  'NCC': 'NCC Consortium: ',
#  'SOLARIS HEPPA': 'SOLARIS HEPPA Consortium: https://solarisheppa.geomar.de',
#  'AER': 'Atmospheric and Environmental Research: http://www.aer.com/',
#  'AoR': 'Astronomical Observatory of Rome: http://web.oa-roma.inaf.it/',
#  'AS-RCEC': 'Research Center for Environmental Changes, Academia Sinica: http://www.rcec.sinica.edu.tw/',
#  'AUoT': 'Aristotle University of Thessaloniki: https://www.auth.gr/en',
#  'AWI': 'Alfred Wegener Institute for Polar and Marine Research: https://www.awi.de',
#  'BAS': 'British Antarctic Survey: https://www.bas.ac.uk/',
#  'BCC': 'Beijing Biocytogen (China): http://www.bbctg.com.cn/',
#  'CAMS': 'Chinese Academy of Meteorological Sciences: http://www.camscma.cn/en.html',
#  'CAS': 'Chinese Academy of Sciences: http://english.cas.cn/',
#  'CCCma': 'Environment and Climate Change Canada: https://www.canada.ca/en/environment-climate-change.html',
#  'CCCR-IITM': 'Indian Institute of Tropical Meteorology: http://www.tropmet.res.in/',
#  'CEDA': 'Centre for Environmental Data Analysis: https://www.ceda.ac.uk/',
#  'CMCC': 'Euro-Mediterranean Center for Climate Change: http://www.cmcc.it/',
#  'CNES': "Centre National d'Études Spatiales: https://www.cnes.fr",
#  'CSIRO': 'Commonwealth Scientific and Industrial Research Organisation: http://www.csiro.au/',
#  'DKRZ': 'German Climate Computing Centre: https://www.dkrz.de/',
#  'DWD': 'German Meteorological Service: http://www.dwd.de/',
#  'EAWAG': 'Swiss Federal Institute of Aquatic Science and Technology: http://www.eawag.ch/en/',
#  'ECMWF': 'European Centre for Medium-Range Weather Forecasts: http://www.ecmwf.int/',
#  'ESSO': 'Indian National Centre for Ocean Information Services: http://www.incois.gov.in/portal/index.jsp',
#  'FMI': 'Finnish Meteorological Institute: http://en.ilmatieteenlaitos.fi/',
#  'FUBerlin': 'Freie Universität Berlin: https://www.fu-berlin.de',
#  'IACETH': 'ETH Zurich: https://ethz.ch',
#  'IFM-GEOMAR': 'GEOMAR Helmholtz Centre for Ocean Research Kiel: http://www.geomar.de/en/',
#  'ImperialCollege': 'Imperial College London: http://www.imperial.ac.uk/',
#  'INM': 'Institute of Numerical Mathematics: http://www.inm.ras.ru/inm_en_ver/index.htm',
#  'IPSL': 'Institut Pierre-Simon Laplace: https://www.ipsl.fr/en/',
#  'ISSI': 'International Space Science Institute: http://www.issibern.ch/',
#  'JAXA': 'Japan Aerospace Exploration Agency: http://global.jaxa.jp/',
#  'KIOST': 'Korea Institute of Ocean Science and Technology: http://eng.kiost.ac/',
#  'KIT': 'Karlsruhe Institute of Technology: http://www.kit.edu/english/',
#  'LLNL': 'Lawrence Livermore National Laboratory: https://www.llnl.gov/',
#  'LPC2E': 'Laboratoire de Physique et Chimie de l’Environnement et de l’Espace: https://www.lpc2e.cnrs.fr',
#  'MOHC': 'Met Office: http://www.metoffice.gov.uk/',
#  'MPI-B': 'Max Planck Institute for Biogeochemistry: http://www.bgc-jena.mpg.de/',
#  'MPI-M': 'Max Planck Institute for Meteorology: http://www.mpimet.mpg.de/en/home.html',
#  'MPS': 'Max Planck Institute for Solar System Research: http://www.mps.mpg.de/en',
#  'MRI': 'Japan Meteorological Agency: http://www.jma.go.jp/jma/indexe.html',
#  'NASA-GISS': 'Goddard Institute for Space Studies: http://www.giss.nasa.gov/',
#  'NASA-GSFC': 'Goddard Space Flight Center: https://www.nasa.gov/centers/goddard/home/index.html',
#  'NASA-JPL': 'Jet Propulsion Laboratory: http://www.jpl.nasa.gov/',
#  'NASA-LaRC': 'Langley Research Center: http://www.nasa.gov/langley',
#  'NCAR': 'National Center for Atmospheric Research: https://ncar.ucar.edu/',
#  'NCAS': 'Uks: http://www.uksresearch.com/',
#  'NERC': 'Natural Environment Research Council: https://www.ukri.org/councils/nerc/',
#  'NIWA': 'National Institute of Water and Atmospheric Research: https://www.niwa.co.nz/',
#  'NOAA-NCEI': 'NOAA National Centers for Environmental Information: https://www.ncei.noaa.gov',
#  'NTU': 'National Taiwan University: http://www.ntu.edu.tw/english/',
#  'NUIST': 'Nanjing University: http://www.nju.edu.cn/english/',
#  'OSU': 'Oregon State University: http://oregonstate.edu/',
#  'PCMDI': 'Lawrence Livermore National Laboratory: https://www.llnl.gov/',
#  'PMOD': 'Physikalisch-Meteorologisches Observatorium Davos: https://www.pmodwrc.ch/',
#  'PNNL-JGCRI': 'Joint Global Change Research Institute: http://www.globalchange.umd.edu/',
#  'PNNL-WACCEM': 'Pacific Northwest National Laboratory: http://www.pnnl.gov/',
#  'RSS': 'Remote Sensing Systems (United States): http://www.remss.com/',
#  'SNU': 'Seoul National University: http://www.snu.ac.kr/index.html',
#  'THU': 'Tsinghua University: http://www.tsinghua.edu.cn/publish/newthuen/',
#  'UA': 'University of Arizona: http://www.arizona.edu/',
#  'UCI': 'University of California, Irvine: http://uci.edu/',
#  'UColorado': 'University of Colorado System: http://www.cu.edu/',
#  'UCSB': 'University of California, Santa Barbara: http://www.ucsb.edu/',
#  'UHH': 'Universität Hamburg: http://www.uni-hamburg.de',
#  'UoBergen': 'University of Bergen: http://www.uib.no/',
#  'UofMD': 'University of Maryland, College Park: http://www.umd.edu/',
#  'UoLeeds': 'University of Leeds: http://www.leeds.ac.uk/',
#  'UoM': 'University of Melbourne: http://www.unimelb.edu.au/',
#  'UoMontreal': 'Université de Montréal: http://www.umontreal.ca/english/',
#  'UoOtago': 'University of Otago: http://www.otago.ac.nz/',
#  'UoOulu': 'University of Oulu: http://www.oulu.fi/english/',
#  'UReading': 'University of Reading: http://www.reading.ac.uk/',
#  'UW': 'University of Washington: http://www.washington.edu/',
#  'VUA': 'Vrije Universiteit Amsterdam: https://vu.nl/'}

# %% [markdown]
# ------

# %% [markdown]
# ## Advanced Framing
# We can actually do all of the above directly by using the `@explicit` tag. This returns only fields which we request directly.

# %%
frame2 = {
    "@type": [
        "mip:institution",
        "mip:consortium"
    ],
    "@explicit": True,
    "consortium:cmip-acronym": "",
    "institution:cmip-acronym": "",
    "consortium:name": "",
    "institution:name": ""
    
}

# %%
# by default clean covers: ['rmld','rmnull','untag','flatten']
data2 = Frame(latest,frame2).clean().filter_empty
data2.data
# Out:
# [{'cmip-acronym': 'MIROC', 'name': 'MIROC Consortium'},
#  {'cmip-acronym': 'NCC', 'name': 'NCC Consortium'},
#  {'cmip-acronym': 'SOLARIS HEPPA', 'name': 'SOLARIS HEPPA Consortium'},
#  {'cmip-acronym': 'AER', 'name': 'Atmospheric and Environmental Research'},
#  {'cmip-acronym': 'AoR', 'name': 'Astronomical Observatory of Rome'},
#  {'cmip-acronym': 'AS-RCEC',
#   'name': 'Research Center for Environmental Changes, Academia Sinica'},
#  {'cmip-acronym': 'AUoT', 'name': 'Aristotle University of Thessaloniki'},
#  {'cmip-acronym': 'AWI',
#   'name': 'Alfred Wegener Institute for Polar and Marine Research'},
#  {'cmip-acronym': 'BAS', 'name': 'British Antarctic Survey'},
#  {'cmip-acronym': 'BCC', 'name': 'Beijing Biocytogen (China)'},
#  {'cmip-acronym': 'CAMS',
#   'name': 'Chinese Academy of Meteorological Sciences'},
#  {'cmip-acronym': 'CAS', 'name': 'Chinese Academy of Sciences'},
#  {'cmip-acronym': 'CCCma', 'name': 'Environment and Climate Change Canada'},
#  {'cmip-acronym': 'CCCR-IITM',
#   'name': 'Indian Institute of Tropical Meteorology'},
#  {'cmip-acronym': 'CEDA', 'name': 'Centre for Environmental Data Analysis'},
#  {'cmip-acronym': 'CMCC',
#   'name': 'Euro-Mediterranean Center for Climate Change'},
#  {'cmip-acronym': 'CNES', 'name': "Centre National d'Études Spatiales"},
#  {'cmip-acronym': 'CSIRO',
#   'name': 'Commonwealth Scientific and Industrial Research Organisation'},
#  {'cmip-acronym': 'DKRZ', 'name': 'German Climate Computing Centre'},
#  {'cmip-acronym': 'DWD', 'name': 'German Meteorological Service'},
#  {'cmip-acronym': 'EAWAG',
#   'name': 'Swiss Federal Institute of Aquatic Science and Technology'},
#  {'cmip-acronym': 'ECMWF',
#   'name': 'European Centre for Medium-Range Weather Forecasts'},
#  {'cmip-acronym': 'ESSO',
#   'name': 'Indian National Centre for Ocean Information Services'},
#  {'cmip-acronym': 'FMI', 'name': 'Finnish Meteorological Institute'},
#  {'cmip-acronym': 'FUBerlin', 'name': 'Freie Universität Berlin'},
#  {'cmip-acronym': 'IACETH', 'name': 'ETH Zurich'},
#  {'cmip-acronym': 'IFM-GEOMAR',
#   'name': 'GEOMAR Helmholtz Centre for Ocean Research Kiel'},
#  {'cmip-acronym': 'ImperialCollege', 'name': 'Imperial College London'},
#  {'cmip-acronym': 'INM', 'name': 'Institute of Numerical Mathematics'},
#  {'cmip-acronym': 'IPSL', 'name': 'Institut Pierre-Simon Laplace'},
#  {'cmip-acronym': 'ISSI', 'name': 'International Space Science Institute'},
#  {'cmip-acronym': 'JAXA', 'name': 'Japan Aerospace Exploration Agency'},
#  {'cmip-acronym': 'KIOST',
#   'name': 'Korea Institute of Ocean Science and Technology'},
#  {'cmip-acronym': 'KIT', 'name': 'Karlsruhe Institute of Technology'},
#  {'cmip-acronym': 'LLNL', 'name': 'Lawrence Livermore National Laboratory'},
#  {'cmip-acronym': 'LPC2E',
#   'name': 'Laboratoire de Physique et Chimie de l’Environnement et de l’Espace'},
#  {'cmip-acronym': 'MOHC', 'name': 'Met Office'},
#  {'cmip-acronym': 'MPI-B', 'name': 'Max Planck Institute for Biogeochemistry'},
#  {'cmip-acronym': 'MPI-M', 'name': 'Max Planck Institute for Meteorology'},
#  {'cmip-acronym': 'MPS',
#   'name': 'Max Planck Institute for Solar System Research'},
#  {'cmip-acronym': 'MRI', 'name': 'Japan Meteorological Agency'},
#  {'cmip-acronym': 'NASA-GISS', 'name': 'Goddard Institute for Space Studies'},
#  {'cmip-acronym': 'NASA-GSFC', 'name': 'Goddard Space Flight Center'},
#  {'cmip-acronym': 'NASA-JPL', 'name': 'Jet Propulsion Laboratory'},
#  {'cmip-acronym': 'NASA-LaRC', 'name': 'Langley Research Center'},
#  {'cmip-acronym': 'NCAR', 'name': 'National Center for Atmospheric Research'},
#  {'cmip-acronym': 'NCAS', 'name': 'Uks'},
#  {'cmip-acronym': 'NERC', 'name': 'Natural Environment Research Council'},
#  {'cmip-acronym': 'NIWA',
#   'name': 'National Institute of Water and Atmospheric Research'},
#  {'cmip-acronym': 'NOAA-NCEI',
#   'name': 'NOAA National Centers for Environmental Information'},
#  {'cmip-acronym': 'NTU', 'name': 'National Taiwan University'},
#  {'cmip-acronym': 'NUIST', 'name': 'Nanjing University'},
#  {'cmip-acronym': 'OSU', 'name': 'Oregon State University'},
#  {'cmip-acronym': 'PCMDI', 'name': 'Lawrence Livermore National Laboratory'},
#  {'cmip-acronym': 'PMOD',
#   'name': 'Physikalisch-Meteorologisches Observatorium Davos'},
#  {'cmip-acronym': 'PNNL-JGCRI',
#   'name': 'Joint Global Change Research Institute'},
#  {'cmip-acronym': 'PNNL-WACCEM',
#   'name': 'Pacific Northwest National Laboratory'},
#  {'cmip-acronym': 'RSS', 'name': 'Remote Sensing Systems (United States)'},
#  {'cmip-acronym': 'SNU', 'name': 'Seoul National University'},
#  {'cmip-acronym': 'THU', 'name': 'Tsinghua University'},
#  {'cmip-acronym': 'UA', 'name': 'University of Arizona'},
#  {'cmip-acronym': 'UCI', 'name': 'University of California, Irvine'},
#  {'cmip-acronym': 'UColorado', 'name': 'University of Colorado System'},
#  {'cmip-acronym': 'UCSB', 'name': 'University of California, Santa Barbara'},
#  {'cmip-acronym': 'UHH', 'name': 'Universität Hamburg'},
#  {'cmip-acronym': 'UoBergen', 'name': 'University of Bergen'},
#  {'cmip-acronym': 'UofMD', 'name': 'University of Maryland, College Park'},
#  {'cmip-acronym': 'UoLeeds', 'name': 'University of Leeds'},
#  {'cmip-acronym': 'UoM', 'name': 'University of Melbourne'},
#  {'cmip-acronym': 'UoMontreal', 'name': 'Université de Montréal'},
#  {'cmip-acronym': 'UoOtago', 'name': 'University of Otago'},
#  {'cmip-acronym': 'UoOulu', 'name': 'University of Oulu'},
#  {'cmip-acronym': 'UReading', 'name': 'University of Reading'},
#  {'cmip-acronym': 'UW', 'name': 'University of Washington'},
#  {'cmip-acronym': 'VUA', 'name': 'Vrije Universiteit Amsterdam'}]

# %%
dict({item.values() for item in data2.data})
# Out:
# {'MPI-M': 'Max Planck Institute for Meteorology',
#  'PCMDI': 'Lawrence Livermore National Laboratory',
#  'PNNL-JGCRI': 'Joint Global Change Research Institute',
#  'LPC2E': 'Laboratoire de Physique et Chimie de l’Environnement et de l’Espace',
#  'UCSB': 'University of California, Santa Barbara',
#  'ECMWF': 'European Centre for Medium-Range Weather Forecasts',
#  'ESSO': 'Indian National Centre for Ocean Information Services',
#  'NERC': 'Natural Environment Research Council',
#  'CCCR-IITM': 'Indian Institute of Tropical Meteorology',
#  'BCC': 'Beijing Biocytogen (China)',
#  'UoM': 'University of Melbourne',
#  'SOLARIS HEPPA': 'SOLARIS HEPPA Consortium',
#  'FUBerlin': 'Freie Universität Berlin',
#  'NASA-GSFC': 'Goddard Space Flight Center',
#  'AS-RCEC': 'Research Center for Environmental Changes, Academia Sinica',
#  'NIWA': 'National Institute of Water and Atmospheric Research',
#  'NOAA-NCEI': 'NOAA National Centers for Environmental Information',
#  'AoR': 'Astronomical Observatory of Rome',
#  'OSU': 'Oregon State University',
#  'UofMD': 'University of Maryland, College Park',
#  'NUIST': 'Nanjing University',
#  'MIROC': 'MIROC Consortium',
#  'CEDA': 'Centre for Environmental Data Analysis',
#  'THU': 'Tsinghua University',
#  'CSIRO': 'Commonwealth Scientific and Industrial Research Organisation',
#  'BAS': 'British Antarctic Survey',
#  'AUoT': 'Aristotle University of Thessaloniki',
#  'NASA-LaRC': 'Langley Research Center',
#  'MPS': 'Max Planck Institute for Solar System Research',
#  'KIT': 'Karlsruhe Institute of Technology',
#  'NCC': 'NCC Consortium',
#  'CAS': 'Chinese Academy of Sciences',
#  'KIOST': 'Korea Institute of Ocean Science and Technology',
#  'JAXA': 'Japan Aerospace Exploration Agency',
#  'CCCma': 'Environment and Climate Change Canada',
#  'CMCC': 'Euro-Mediterranean Center for Climate Change',
#  'DWD': 'German Meteorological Service',
#  'ImperialCollege': 'Imperial College London',
#  'FMI': 'Finnish Meteorological Institute',
#  'MPI-B': 'Max Planck Institute for Biogeochemistry',
#  'UW': 'University of Washington',
#  'IPSL': 'Institut Pierre-Simon Laplace',
#  'LLNL': 'Lawrence Livermore National Laboratory',
#  'PNNL-WACCEM': 'Pacific Northwest National Laboratory',
#  'UoMontreal': 'Université de Montréal',
#  'NCAR': 'National Center for Atmospheric Research',
#  'UA': 'University of Arizona',
#  'ISSI': 'International Space Science Institute',
#  'IFM-GEOMAR': 'GEOMAR Helmholtz Centre for Ocean Research Kiel',
#  'MOHC': 'Met Office',
#  'RSS': 'Remote Sensing Systems (United States)',
#  'UoBergen': 'University of Bergen',
#  'UoOtago': 'University of Otago',
#  'EAWAG': 'Swiss Federal Institute of Aquatic Science and Technology',
#  'IACETH': 'ETH Zurich',
#  'DKRZ': 'German Climate Computing Centre',
#  'MRI': 'Japan Meteorological Agency',
#  'UCI': 'University of California, Irvine',
#  'UoLeeds': 'University of Leeds',
#  'AWI': 'Alfred Wegener Institute for Polar and Marine Research',
#  'UReading': 'University of Reading',
#  'CNES': "Centre National d'Études Spatiales",
#  'UColorado': 'University of Colorado System',
#  'UHH': 'Universität Hamburg',
#  'VUA': 'Vrije Universiteit Amsterdam',
#  'NASA-GISS': 'Goddard Institute for Space Studies',
#  'INM': 'Institute of Numerical Mathematics',
#  'SNU': 'Seoul National University',
#  'UoOulu': 'University of Oulu',
#  'NCAS': 'Uks',
#  'NASA-JPL': 'Jet Propulsion Laboratory',
#  'NTU': 'National Taiwan University',
#  'PMOD': 'Physikalisch-Meteorologisches Observatorium Davos',
#  'CAMS': 'Chinese Academy of Meteorological Sciences',
#  'AER': 'Atmospheric and Environmental Research'}

# %% [markdown]
# ------

# %% [markdown]
# ## Case Specific Example
# #### Selecting institutions from CMIP6Plus only
# Here we look at the source_id entries, and the organisations which have been references within those.

# %%
frame3 = {
    "@context": {
    "@vocab": "source-id:"
    
  },
    "@type": "mip:source-id",
    "source-id:name":"",
    "source-id:organisation-id": {
        "@type": [
            "mip:institution",
            "mip:consortium"
        ],
        "@explicit": True,
        "consortium:cmip-acronym": "",
        "institution:cmip-acronym": "",
        "consortium:name": "",
        "institution:name": "",
        
    },
    "@explicit": True
}

# %%
data3 = Frame(latest,frame3).clean()
data3.print
# Out:
# [{'name': 'GISS-E2-1-G',
#   'organisation-id': {'cmip-acronym': 'NASA-GISS',
#                       'name': 'Goddard Institute for Space Studies'}},
#  {'name': 'HadGEM3-GC31-LL',
#   'organisation-id': {'cmip-acronym': 'MOHC', 'name': 'Met Office'}},
#  {'name': 'MIROC6',
#   'organisation-id': {'cmip-acronym': 'MIROC', 'name': 'MIROC Consortium'}},
#  {'name': 'MPI-ESM1-2-HR',
#   'organisation-id': {'cmip-acronym': 'MPI-M',
#                       'name': 'Max Planck Institute for Meteorology'}},
#  {'name': 'MPI-ESM1-2-LR',
#   'organisation-id': {'cmip-acronym': 'MPI-M',
#                       'name': 'Max Planck Institute for Meteorology'}},
#  {'name': 'NorESM2-LM',
#   'organisation-id': {'cmip-acronym': 'NCC', 'name': 'NCC Consortium'}}]

# %%
dict(set([i['organisation-id'].values() for i in data3.data]))
# Out:
# {'MPI-M': 'Max Planck Institute for Meteorology',
#  'NASA-GISS': 'Goddard Institute for Space Studies',
#  'NCC': 'NCC Consortium',
#  'MIROC': 'MIROC Consortium',
#  'MOHC': 'Met Office'}
