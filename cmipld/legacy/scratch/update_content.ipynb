# %%
import json
from pyld import jsonld
import os, re, sys
from glob import glob
from pprint import pprint

def rd(f):
    return json.load(open(f))

def wt(d,f):
    return json.dump(d,open(f,'w'),indent=4)

# %%
loc = '/Users/daniel.ellis/WIPwork/WCRP-universe/src-data/'
dirs = os.listdir(loc)
print(dirs)
# Out:
# ['del.ipynb', '.DS_Store', 'source-type', 'consortium', 'license', 'archive', 'frequency', '_context_', 'activity', 'product', 'mip', 'grid-label', 'institution', 'resolution', '.github', 'realm']

# %%
section = f'{loc}realm'
js = glob(f'{section}/*.json')

pprint(rd(js[0]))
# Out:
# {'@context': '_context_',
#  'description': 'Ocean Biogeochemistry',
#  'id': 'ocnbgchem',
#  'label': 'ocnBgchem',
#  'long_label': 'Ocean Biogeochemistry',
#  'type': ['wcrp:realm', 'universal']}

# %%
write = False



ctx = rd(glob(f'{section}/_context_')[0])['@context']

pprint(ctx)

ids = []
for i in ctx:
    if isinstance(i,dict):
        for j,k in i.items():
            
            assert '-' not in j
            
            if '@id' in str(k):
                ids.append(j)
            
print('links', ids)





# replace
for f in js:
    print(f)
    data = rd(f)

    data['id'] = data['id'].lower().replace('_','-')    
      
    # data['long_label'] = data['long_name']
    # del data['long_name']
    # data['label'] = data['id']
    
    # mt = {}
    # for i in data['mip_tables']:
    #     k = i['@id']
    #     del i['@id']
    #     mt[k] = dict(zip([d.lower().replace('-','_') for d in i.keys()],i.values()))
        
    # data['mip_tables'] = mt
    
    
    
    # fix keys to have no -
    data= dict(zip([d.lower().replace('-','_') for d in data.keys()],data.values()))
            
            
    stop = False
    

    for nm in ['name','cmip_acronym','kind','table_id']:
        if nm in data:
            if 'label' in data and data['label'] == data[nm]:
                del data['label']
            else: 
                assert 'label' not in data
            
            data['label'] = data[nm]
            del data[nm] 
                
                    
    # id fix
    for z in ids:
        
        # if z not in data: continue
        
        
        if isinstance(data[z],list):
            data[z] = [i.lower().replace('_','-') for i in data[z]]
            
        if isinstance(data[z],dict):
            values = []
            for p in data[z].values():
                if isinstance(p,dict):
                    # normal keys are a '_' 
                    p = dict(zip([d.lower().replace('-','_') for d in p.keys()],p.values()))
                values.append(p)
                
            # ids are a hypen
            data[z]= dict(zip([d.lower().replace('_','-') for d in data[z].keys()],values))
            
            


    # if 'source_id' in data:
    #     del data['source_id']
    
    

            
    if write:        
        if '_' in f.split('/')[-1]:
            rename=True
            os.remove(f)
            f = f"{section}/{data['id']}.json"
            print(f)
            
        wt(data,f)
        
        assert os.path.exists(f)
    
    pprint(data)
# Out:
# ['../_context_',
#  {'@base': 'https://wcrp-cmip.github.io/MIP-variables/variables/',
#   '@vocab': 'https://wcrp-cmip.github.io/MIP-variables/variables/',
#   'mip_tables': {'@context': 'https://wcrp-cmip.github.io/MIP-variables/tables/_context_',
#                  '@reverse': 'https://wcrp-cmip.github.io/MIP-variables/tables/variable_entry'},
#   'standard_name': {'@context': 'https://wcrp-cmip.github.io/CF/standard_name/_context_',
#                     '@type': '@id'}}]
# links ['standard_name']
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/gigyr.hfgeoubed.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacellg',
#  'cell_methods': 'area: time: mean where grounded_ice_sheet (comment: '
#                  'mask=sfgrlf)',
#  'comment': 'Upward geothermal heat flux per unit area into the base of '
#             'grounded land ice. This is related to the geothermal heat flux '
#             'out of the bedrock, but may be modified by horizontal transport '
#             'due to run-off and by melting at the interface.',
#  'dimensions': ['xgre', 'ygre', 'time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'gigyr.hfgeoubed',
#  'label': 'gigyr.hfgeoubed',
#  'long_label': 'Geothermal Heat Flux Beneath Land Ice',
#  'mip_tables': {'gigyr': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'hfgeoubed',
#  'positive': '',
#  'standard_name': 'upward_geothermal_heat_flux_at_ground_level_in_land_ice',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obyrlev.exparag.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Downward flux of Aragonite',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'obyrlev.exparag',
#  'label': 'obyrlev.exparag',
#  'long_label': 'Downward Flux of Aragonite',
#  'mip_tables': {'obyrlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'exparag',
#  'positive': 'down',
#  'standard_name': 'sinking_mole_flux_of_aragonite_expressed_as_carbon_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/ap3hrptlev.rsucsbnd.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean time: point',
#  'comment': 'Calculated with aerosols but without clouds. This is a standard '
#             'clear-sky calculation',
#  'dimensions': ['longitude', 'latitude', 'alevhalf', 'spectband', 'time1'],
#  'dtype': 'real',
#  'frequency': '3hrPt',
#  'id': 'ap3hrptlev.rsucsbnd',
#  'label': 'ap3hrptlev.rsucsbnd',
#  'long_label': 'Upwelling Clear-Sky Shortwave Radiation at Each Level for Each '
#                'Band',
#  'mip_tables': {'ap3hrptlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rsucsbnd',
#  'positive': 'up',
#  'standard_name': 'upwelling_shortwave_flux_in_air_assuming_clear_sky',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/ae3hrpt.rsuscsafbnd.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'time: point',
#  'comment': 'Calculated in the absence of aerosols and clouds, following Ghan '
#             '(ACP, 2013). This requires a double-call in the radiation code '
#             'with precisely the same meteorology.',
#  'dimensions': ['longitude', 'latitude', 'spectband', 'time1'],
#  'dtype': 'real',
#  'frequency': '3hrPt',
#  'id': 'ae3hrpt.rsuscsafbnd',
#  'label': 'ae3hrpt.rsuscsafbnd',
#  'long_label': 'Surface Upwelling Clear-Sky, Aerosol-Free Shortwave Radiation '
#                'in Bands',
#  'mip_tables': {'ae3hrpt': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['aerosol'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rsuscsafbnd',
#  'positive': 'up',
#  'standard_name': 'surface_upwelling_shortwave_flux_in_air_assuming_clear_sky_and_no_aerosol',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmon.hfgeou.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Upward geothermal heat flux per unit area on the sea floor',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmon.hfgeou',
#  'label': 'opmon.hfgeou',
#  'long_label': 'Upward Geothermal Heat Flux at Sea Floor',
#  'mip_tables': {'opmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'hfgeou',
#  'positive': 'up',
#  'standard_name': 'upward_geothermal_heat_flux_at_sea_floor',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/aemonz.hno3.json
# {'@context': '_context_',
#  'cell_measures': '',
#  'cell_methods': 'longitude: mean time: mean',
#  'comment': 'Mole fraction is used in the construction '
#             'mole_fraction_of_X_in_Y, where X is a material constituent of Y.',
#  'dimensions': ['latitude', 'plev39', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'aemonz.hno3',
#  'label': 'aemonz.hno3',
#  'long_label': 'HNO3 Volume Mixing Ratio',
#  'mip_tables': {'aemonz': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['aerosol'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'hno3',
#  'positive': '',
#  'standard_name': 'mole_fraction_of_nitric_acid_in_air',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol mol-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opdec.tauvo.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'This is the stress on the liquid ocean from overlying atmosphere, '
#             'sea ice, ice shelf, etc.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'dec',
#  'id': 'opdec.tauvo',
#  'label': 'opdec.tauvo',
#  'long_label': 'Sea Water Surface Downward Y Stress',
#  'mip_tables': {'opdec': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'tauvo',
#  'positive': 'down',
#  'standard_name': 'downward_y_stress_at_sea_water_surface',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'N m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/aemon.reffclwtop.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Droplets are liquid only.  This is the effective radius as seen '
#             'from space over liquid cloudy portion of grid cell. This is the '
#             'value from uppermost model layer with liquid cloud or, if '
#             'available, or for some models it is the sum over all liquid cloud '
#             'tops, no matter where they occur, as long as they are seen from '
#             'the top of the atmosphere (TOA) each time sample when computing '
#             'monthly mean. Reported values are weighted by total liquid cloud '
#             'top fraction of  (as seen from TOA) each time sample when '
#             'computing monthly mean.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'aemon.reffclwtop',
#  'label': 'aemon.reffclwtop',
#  'long_label': 'Cloud-Top Effective Droplet Radius',
#  'mip_tables': {'aemon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['aerosol'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'reffclwtop',
#  'positive': '',
#  'standard_name': 'effective_radius_of_cloud_liquid_water_particles_at_liquid_water_cloud_top',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'm',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmonlev.prthetao.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'A passive tracer in an ocean model which is subject to an '
#             'externally imposed perturbative surface heat flux. The passive '
#             'tracer is initialised to the potential temperature in the control '
#             'climate before the perturbation is imposed. Its surface flux is '
#             'the heat flux from the atmosphere, not including the imposed '
#             'perturbation, and is converted to a passive tracer increment as '
#             'if it were being added to potential temperature. The passive '
#             'tracer is transported within the ocean as if it were potential '
#             'temperature. ',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmonlev.prthetao',
#  'label': 'opmonlev.prthetao',
#  'long_label': 'Sea Water Redistributed Potential Temperature',
#  'mip_tables': {'opmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'prthetao',
#  'positive': '',
#  'standard_name': 'sea_water_redistributed_potential_temperature',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'degC',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.fndep.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'Surface deposition rate of nitrogen.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.fndep',
#  'label': 'lpmon.fndep',
#  'long_label': 'Dry and Wet Deposition of Reactive Nitrogen onto Land',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'fNdep',
#  'positive': '',
#  'standard_name': 'minus_tendency_of_atmosphere_mass_content_of_nitrogen_compounds_expressed_as_nitrogen_due_to_deposition',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/apday.clisccp.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Percentage cloud cover in optical depth categories.',
#  'dimensions': ['longitude', 'latitude', 'plev7c', 'tau', 'time'],
#  'dtype': 'real',
#  'frequency': 'day',
#  'id': 'apday.clisccp',
#  'label': 'apday.clisccp',
#  'long_label': 'ISCCP Cloud Area Percentage',
#  'mip_tables': {'apday': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'clisccp',
#  'positive': '',
#  'standard_name': 'cloud_area_fraction_in_atmosphere_layer',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '%',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/gigyr.yvelsurf.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacellg',
#  'cell_methods': 'area: time: mean where ice_sheet',
#  'comment': "A velocity is a vector quantity. 'y' indicates a vector component "
#             "along the grid y-axis, positive with increasing y. 'Land ice' "
#             'means glaciers, ice-caps and ice-sheets resting on bedrock and '
#             "also includes ice-shelves. The surface called 'surface' means the "
#             "lower boundary of the atmosphere.'",
#  'dimensions': ['xgre', 'ygre', 'time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'gigyr.yvelsurf',
#  'label': 'gigyr.yvelsurf',
#  'long_label': 'Y-Component of Land Ice Surface Velocity',
#  'mip_tables': {'gigyr': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'yvelsurf',
#  'positive': '',
#  'standard_name': 'land_ice_surface_y_velocity',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'm s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obyrlev.pbsi.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': "'Mole concentration' means number of moles per unit volume, also "
#             "called 'molarity', and is used in the construction "
#             'mole_concentration_of_X_in_Y, where X is a material constituent '
#             'of Y.  A chemical or biological species denoted by X may be '
#             "described by a single term such as 'nitrogen' or a phrase such as "
#             "'nox_expressed_as_nitrogen'. The specification of a physical "
#             'process by the phrase due_to_process means that the quantity '
#             'named is a  single term in a sum of terms which together compose '
#             'the general quantity  named by omitting the phrase.  '
#             "'tendency_of_X' means derivative of X with respect to time.",
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'obyrlev.pbsi',
#  'label': 'obyrlev.pbsi',
#  'long_label': 'Biogenic Silicon Production',
#  'mip_tables': {'obyrlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'pbsi',
#  'positive': '',
#  'standard_name': 'tendency_of_mole_concentration_of_silicon_in_sea_water_due_to_biological_production',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obmon.phydiazos.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'carbon concentration from the diazotrophic phytoplankton '
#             'component alone',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'obmon.phydiazos',
#  'label': 'obmon.phydiazos',
#  'long_label': 'Surface Mole Concentration of Diazotrophs Expressed as Carbon '
#                'in Sea Water',
#  'mip_tables': {'obmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'phydiazos',
#  'positive': '',
#  'standard_name': 'mole_concentration_of_diazotrophic_phytoplankton_expressed_as_carbon_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmonlev.volcello.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: sum where sea time: mean',
#  'comment': 'grid-cell volume ca. 2000.',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmonlev.volcello',
#  'label': 'opmonlev.volcello',
#  'long_label': 'Ocean Grid-Cell Volume',
#  'mip_tables': {'opmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'volcello',
#  'positive': '',
#  'standard_name': 'ocean_volume',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'm3',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/giayr.sftflf.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacellg',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Percentage of grid cell covered by floating ice shelf, the '
#             'component of the ice sheet that is flowing over sea water',
#  'dimensions': ['xant', 'yant', 'time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'giayr.sftflf',
#  'label': 'giayr.sftflf',
#  'long_label': 'Floating Ice Shelf Area Percentage',
#  'mip_tables': {'giayr': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'sftflf',
#  'positive': '',
#  'standard_name': 'floating_ice_shelf_area_fraction',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '%',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obmon.limfemisc.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Phytoplankton are algae that grow where there is sufficient light '
#             "to support photosynthesis. 'Miscellaneous phytoplankton' are all "
#             'those phytoplankton that are not diatoms, diazotrophs, calcareous '
#             'phytoplankton, picophytoplankton or other separately named '
#             "components of the phytoplankton population. 'Iron growth "
#             "limitation' means the ratio of the growth rate of a species "
#             'population in the environment (where there is a finite '
#             'availability of iron) to the theoretical growth rate if there '
#             'were no such limit on iron availability.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'obmon.limfemisc',
#  'label': 'obmon.limfemisc',
#  'long_label': 'Iron Limitation of Other Phytoplankton',
#  'mip_tables': {'obmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'limfemisc',
#  'positive': '',
#  'standard_name': 'iron_growth_limitation_of_miscellaneous_phytoplankton',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/giayr.yvelmean.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacellg',
#  'cell_methods': 'area: time: mean where ice_sheet',
#  'comment': 'The vertical mean land ice velocity is the average from the '
#             'bedrock to the surface of the ice',
#  'dimensions': ['xant', 'yant', 'time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'giayr.yvelmean',
#  'label': 'giayr.yvelmean',
#  'long_label': 'Y-Component of Land Ice Vertical Mean Velocity',
#  'mip_tables': {'giayr': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'yvelmean',
#  'positive': '',
#  'standard_name': 'land_ice_vertical_mean_y_velocity',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'm s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/giamon.snm.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacellg',
#  'cell_methods': 'area: time: mean where ice_sheet',
#  'comment': 'The total surface snow melt rate on the land portion of the grid '
#             'cell divided by the land area in the grid cell; report as zero '
#             'for snow-free land regions and missing where there is no land.',
#  'dimensions': ['xant', 'yant', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'giamon.snm',
#  'label': 'giamon.snm',
#  'long_label': 'Surface Snow Melt',
#  'mip_tables': {'giamon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce', 'land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'snm',
#  'positive': '',
#  'standard_name': 'surface_snow_melt_flux',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/aemonlev.mmraerh2o.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Mass fraction is used in the construction '
#             'mass_fraction_of_X_in_Y, where X is a material constituent of Y. '
#             'It means the ratio of the mass of X to the mass of Y (including '
#             "X). 'Aerosol' means the system of suspended liquid or solid "
#             'particles in air (except cloud droplets) and their carrier gas, '
#             "the air itself. 'Ambient_aerosol' means that the aerosol is "
#             'measured or modelled at the ambient state of pressure, '
#             'temperature and relative humidity that exists in its immediate '
#             "environment. 'Ambient aerosol particles' are aerosol particles "
#             'that have taken up ambient water through hygroscopic growth. The '
#             'extent of hygroscopic growth depends on the relative humidity and '
#             'the composition of the particles.',
#  'dimensions': ['longitude', 'latitude', 'alevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'aemonlev.mmraerh2o',
#  'label': 'aemonlev.mmraerh2o',
#  'long_label': 'Aerosol Water Mass Mixing Ratio',
#  'mip_tables': {'aemonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['aerosol'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'mmraerh2o',
#  'positive': '',
#  'standard_name': 'mass_fraction_of_water_in_ambient_aerosol_particles_in_air',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg kg-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obmon.epp100.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'In accordance with common usage in geophysical disciplines, '
#             "'flux' implies per unit area, called 'flux density' in physics.   "
#             "'Sinking' is the gravitational settling of particulate matter "
#             'suspended in a liquid. A sinking flux is positive downwards and '
#             'is calculated relative to the movement of the surrounding fluid.',
#  'dimensions': ['longitude', 'latitude', 'time', 'depth100m'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'obmon.epp100',
#  'label': 'obmon.epp100',
#  'long_label': 'Downward Flux of Particulate Phosphorus',
#  'mip_tables': {'obmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'epp100',
#  'positive': '',
#  'standard_name': 'sinking_mole_flux_of_particulate_organic_phosphorus_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/apmonlev.rsdcs.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Downwelling clear-sky shortwave radiation (includes the fluxes at '
#             'the surface and top-of-atmosphere)',
#  'dimensions': ['longitude', 'latitude', 'alevhalf', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'apmonlev.rsdcs',
#  'label': 'apmonlev.rsdcs',
#  'long_label': 'Downwelling Clear-Sky Shortwave Radiation',
#  'mip_tables': {'apmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rsdcs',
#  'positive': 'down',
#  'standard_name': 'downwelling_shortwave_flux_in_air_assuming_clear_sky',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/ap1hrpt.ta.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean time: point',
#  'comment': 'Air Temperature',
#  'dimensions': ['longitude', 'latitude', 'plev3', 'time1'],
#  'dtype': 'real',
#  'frequency': '1hrPt',
#  'id': 'ap1hrpt.ta',
#  'label': 'ap1hrpt.ta',
#  'long_label': 'Air Temperature',
#  'mip_tables': {'ap1hrpt': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'ta',
#  'positive': '',
#  'standard_name': 'air_temperature',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'K',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obmonlev.bacc.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Sum of bacterial carbon component concentrations',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'obmonlev.bacc',
#  'label': 'obmonlev.bacc',
#  'long_label': 'Bacterial Carbon Concentration',
#  'mip_tables': {'obmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'bacc',
#  'positive': '',
#  'standard_name': 'mole_concentration_of_bacteria_expressed_as_carbon_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmon.fgcfc12.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'gas exchange flux of CFC12',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmon.fgcfc12',
#  'label': 'opmon.fgcfc12',
#  'long_label': 'Surface Downward CFC12 Flux',
#  'mip_tables': {'opmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'fgcfc12',
#  'positive': 'down',
#  'standard_name': 'surface_downward_mole_flux_of_cfc12',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opdeclev.uo.json
# {'@context': '_context_',
#  'cell_measures': '--OPT',
#  'cell_methods': 'time: mean',
#  'comment': 'Prognostic x-ward velocity component resolved by the model.',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'dec',
#  'id': 'opdeclev.uo',
#  'label': 'opdeclev.uo',
#  'long_label': 'Sea Water X Velocity',
#  'mip_tables': {'opdeclev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'uo',
#  'positive': '',
#  'standard_name': 'sea_water_x_velocity',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'm s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmon.vsfevap.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'zero for models using real water fluxes.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmon.vsfevap',
#  'label': 'opmon.vsfevap',
#  'long_label': 'Virtual Salt Flux into Sea Water Due to Evaporation',
#  'mip_tables': {'opmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'vsfevap',
#  'positive': '',
#  'standard_name': 'virtual_salt_flux_into_sea_water_due_to_evaporation',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/apday.prc.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Convective precipitation at surface; includes both liquid and '
#             'solid phases.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'day',
#  'id': 'apday.prc',
#  'label': 'apday.prc',
#  'long_label': 'Convective Precipitation',
#  'mip_tables': {'apday': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'prc',
#  'positive': '',
#  'standard_name': 'convective_precipitation_flux',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.mrtws.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'Mass of water in all phases and in all components including soil, '
#             'canopy, vegetation, ice sheets, rivers and ground water.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.mrtws',
#  'label': 'lpmon.mrtws',
#  'long_label': 'Terrestrial Water Storage',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'mrtws',
#  'positive': '',
#  'standard_name': 'land_water_amount',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/siday.siconca.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Percentage of grid cell covered by sea ice',
#  'dimensions': ['longitude', 'latitude', 'time', 'typesi'],
#  'dtype': 'real',
#  'frequency': 'day',
#  'id': 'siday.siconca',
#  'label': 'siday.siconca',
#  'long_label': 'Sea-Ice Area Percentage (Atmospheric Grid)',
#  'mip_tables': {'siday': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['seaIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'siconca',
#  'positive': '',
#  'standard_name': 'sea_ice_area_fraction',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '%',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.nsoil.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'Report missing data over ocean grid cells. For fractional land '
#             'report value averaged over the land fraction.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.nsoil',
#  'label': 'lpmon.nsoil',
#  'long_label': 'Nitrogen Mass in Soil Pool',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'nSoil',
#  'positive': '',
#  'standard_name': 'soil_mass_content_of_nitrogen',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmon.tossq.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Square of temperature of liquid ocean.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmon.tossq',
#  'label': 'opmon.tossq',
#  'long_label': 'Square of Sea Surface Temperature',
#  'mip_tables': {'opmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'tossq',
#  'positive': '',
#  'standard_name': 'square_of_sea_surface_temperature',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'degC2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/liday.lwsnl.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'The total mass of liquid water contained interstitially within '
#             'the whole depth of the snow layer of the land portion of a grid '
#             'cell divided by the area of the land portion of the cell.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'day',
#  'id': 'liday.lwsnl',
#  'label': 'liday.lwsnl',
#  'long_label': 'Liquid Water Content of Snow Layer',
#  'mip_tables': {'liday': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce', 'land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'lwsnl',
#  'positive': '',
#  'standard_name': 'liquid_water_content_of_surface_snow',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/aemonlev.lossn2o.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'monthly averaged atmospheric loss',
#  'dimensions': ['longitude', 'latitude', 'alevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'aemonlev.lossn2o',
#  'label': 'aemonlev.lossn2o',
#  'long_label': 'Monthly Loss of Atmospheric Nitrous Oxide',
#  'mip_tables': {'aemonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['aerosol'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'lossn2o',
#  'positive': '',
#  'standard_name': 'tendency_of_atmosphere_mole_concentration_of_nitrous_oxide_due_to_chemical_destruction',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/ap3hrptlev.co2.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean time: point',
#  'comment': 'Mole fraction is used in the construction '
#             'mole_fraction_of_X_in_Y, where X is a material constituent of Y.',
#  'dimensions': ['longitude', 'latitude', 'alevel', 'time1'],
#  'dtype': 'real',
#  'frequency': '3hrPt',
#  'id': 'ap3hrptlev.co2',
#  'label': 'ap3hrptlev.co2',
#  'long_label': 'Mole Fraction of CO2',
#  'mip_tables': {'ap3hrptlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'co2',
#  'positive': '',
#  'standard_name': 'mole_fraction_of_carbon_dioxide_in_air',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol mol-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/apsubhrptsite.rldcs.json
# {'@context': '_context_',
#  'cell_measures': '',
#  'cell_methods': 'area: point time: point',
#  'comment': 'Downwelling clear-sky longwave radiation (includes the fluxes at '
#             'the surface and TOA)',
#  'dimensions': ['alevhalf', 'site', 'time1'],
#  'dtype': 'real',
#  'frequency': 'subhrPt',
#  'id': 'apsubhrptsite.rldcs',
#  'label': 'apsubhrptsite.rldcs',
#  'long_label': 'Downwelling Clear-Sky Longwave Radiation',
#  'mip_tables': {'apsubhrptsite': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rldcs',
#  'positive': 'down',
#  'standard_name': 'downwelling_longwave_flux_in_air_assuming_clear_sky',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/aemon.drybc.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Dry deposition includes gravitational settling and turbulent '
#             'deposition.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'aemon.drybc',
#  'label': 'aemon.drybc',
#  'long_label': 'Dry Deposition Rate of Black Carbon Aerosol Mass',
#  'mip_tables': {'aemon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['aerosol'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'drybc',
#  'positive': '',
#  'standard_name': 'minus_tendency_of_atmosphere_mass_content_of_elemental_carbon_dry_aerosol_particles_due_to_dry_deposition',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/apday.hursmincrop.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where crops time: minimum',
#  'comment': 'The relative humidity with respect to liquid water for T> 0 C, '
#             'and with respect to ice for T<0 C.',
#  'dimensions': ['longitude', 'latitude', 'time', 'height2m'],
#  'dtype': 'real',
#  'frequency': 'day',
#  'id': 'apday.hursmincrop',
#  'label': 'apday.hursmincrop',
#  'long_label': 'Daily Minimum Near-Surface Relative Humidity over Crop Tile',
#  'mip_tables': {'apday': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'hursminCrop',
#  'positive': '',
#  'standard_name': 'relative_humidity',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '%',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.c14veg.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'Carbon-14 mass content per unit area in vegetation (any living '
#             'plants e.g. trees, shrubs, grass).',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.c14veg',
#  'label': 'lpmon.c14veg',
#  'long_label': 'Mass of 14C in Vegetation',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'c14Veg',
#  'positive': '',
#  'standard_name': 'vegetation_mass_content_of_14C',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.flitterfire.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'Required for unambiguous separation of vegetation and soil + '
#             'litter turnover times, since total fire flux draws from both '
#             'sources',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.flitterfire',
#  'label': 'lpmon.flitterfire',
#  'long_label': 'Carbon Mass Flux from Litter, CWD or any non-Living Pool into '
#                'Atmosphere Due to CO2 Emission from All Fire [kgC m-2 s-1]',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'fLitterFire',
#  'positive': '',
#  'standard_name': 'surface_upward_mass_flux_of_carbon_dioxide_expressed_as_carbon_due_to_emission_from_litter_in_fires',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lp6hrpt.mrsos.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: point',
#  'comment': 'The mass of water in all phases in the upper 10cm of the  soil '
#             'layer.',
#  'dimensions': ['longitude', 'latitude', 'time1', 'sdepth1'],
#  'dtype': 'real',
#  'frequency': '6hrPt',
#  'id': 'lp6hrpt.mrsos',
#  'label': 'lp6hrpt.mrsos',
#  'long_label': 'Moisture in Upper Portion of Soil Column',
#  'mip_tables': {'lp6hrpt': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'mrsos',
#  'positive': '',
#  'standard_name': 'mass_content_of_water_in_soil_layer',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/ap3hrpt.clisccp.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean time: point',
#  'comment': 'Percentage cloud cover in optical depth categories.',
#  'dimensions': ['longitude', 'latitude', 'plev7c', 'tau', 'time1'],
#  'dtype': 'real',
#  'frequency': '3hrPt',
#  'id': 'ap3hrpt.clisccp',
#  'label': 'ap3hrpt.clisccp',
#  'long_label': 'ISCCP Cloud Area Percentage',
#  'mip_tables': {'ap3hrpt': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'clisccp',
#  'positive': '',
#  'standard_name': 'cloud_area_fraction_in_atmosphere_layer',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '%',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/gigmon.rlds.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacellg',
#  'cell_methods': 'area: time: mean where ice_sheet',
#  'comment': "The surface called 'surface' means the lower boundary of the "
#             "atmosphere. 'longwave' means longwave radiation. Downwelling "
#             "radiation is radiation from above. It does not mean 'net "
#             "downward'. When thought of as being incident on a surface, a "
#             "radiative flux is sometimes called 'irradiance'. In addition, it "
#             'is identical with the quantity measured by a cosine-collector '
#             "light-meter and sometimes called 'vector irradiance'. In "
#             "accordance with common usage in geophysical disciplines, 'flux' "
#             "implies per unit area, called 'flux density' in physics.",
#  'dimensions': ['xgre', 'ygre', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'gigmon.rlds',
#  'label': 'gigmon.rlds',
#  'long_label': 'Surface Downwelling Longwave Radiation',
#  'mip_tables': {'gigmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce', 'land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rlds',
#  'positive': 'down',
#  'standard_name': 'surface_downwelling_longwave_flux_in_air',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obmon.baccos.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Sum of bacterial carbon component concentrations',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'obmon.baccos',
#  'label': 'obmon.baccos',
#  'long_label': 'Surface Bacterial Carbon Concentration',
#  'mip_tables': {'obmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'baccos',
#  'positive': '',
#  'standard_name': 'mole_concentration_of_bacteria_expressed_as_carbon_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmon.friver.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'computed as the river flux of water into the ocean divided by the '
#             'area of the ocean portion of the grid cell.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmon.friver',
#  'label': 'opmon.friver',
#  'long_label': 'Water Flux into Sea Water from Rivers',
#  'mip_tables': {'opmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'friver',
#  'positive': '',
#  'standard_name': 'water_flux_into_sea_water_from_rivers',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obmonlev.dissoc.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Sum of dissolved carbon component concentrations explicitly '
#             'represented (i.e. not ~40 uM refractory unless explicit)',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'obmonlev.dissoc',
#  'label': 'obmonlev.dissoc',
#  'long_label': 'Dissolved Organic Carbon Concentration',
#  'mip_tables': {'obmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'dissoc',
#  'positive': '',
#  'standard_name': 'mole_concentration_of_dissolved_organic_carbon_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/apmon.rsdscs.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Surface solar irradiance clear sky for UV calculations',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'apmon.rsdscs',
#  'label': 'apmon.rsdscs',
#  'long_label': 'Surface Downwelling Clear-Sky Shortwave Radiation',
#  'mip_tables': {'apmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rsdscs',
#  'positive': 'down',
#  'standard_name': 'surface_downwelling_shortwave_flux_in_air_assuming_clear_sky',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/simon.siextents.json
# {'@context': '_context_',
#  'cell_measures': '',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Total area of all Southern-Hemisphere grid cells that are covered '
#             'by at least 15 % areal fraction of sea ice',
#  'dimensions': ['time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'simon.siextents',
#  'label': 'simon.siextents',
#  'long_label': 'Sea-Ice Extent South',
#  'mip_tables': {'simon': {'mip_era': 'obs4mips'}},
#  'modeling_realm': ['seaIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'siextents',
#  'positive': '',
#  'standard_name': 'sea_ice_extent',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '1e6 km2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmon.tob.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Potential temperature at the ocean bottom-most grid cell.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmon.tob',
#  'label': 'opmon.tob',
#  'long_label': 'Sea Water Potential Temperature at Sea Floor',
#  'mip_tables': {'opmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'tob',
#  'positive': '',
#  'standard_name': 'sea_water_potential_temperature_at_sea_floor',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'degC',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/aemon.abs550aer.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Optical thickness of atmospheric aerosols at wavelength 550 '
#             'nanometers.',
#  'dimensions': ['longitude', 'latitude', 'time', 'lambda550nm'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'aemon.abs550aer',
#  'label': 'aemon.abs550aer',
#  'long_label': 'Ambient Aerosol Absorption Optical Thickness at 550nm',
#  'mip_tables': {'aemon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['aerosol'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'abs550aer',
#  'positive': '',
#  'standard_name': 'atmosphere_absorption_optical_thickness_due_to_ambient_aerosol_particles',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
# ...
#             'by the standard acceleration due to gravity. It is numerically '
#             'similar to the altitude (or geometric height) and not to the '
#             'quantity with standard name height, which is relative to the '
#             'surface.',
#  'dimensions': ['alevel', 'site', 'time1'],
#  'dtype': 'real',
#  'frequency': 'subhrPt',
#  'id': 'apsubhrptsite.zg',
#  'label': 'apsubhrptsite.zg',
#  'long_label': 'Geopotential Height',
#  'mip_tables': {'apsubhrptsite': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'zg',
#  'positive': '',
#  'standard_name': 'geopotential_height',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'm',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/giayr.tendlicalvf.json
# {'@context': '_context_',
#  'cell_measures': '',
#  'cell_methods': 'area: sum where ice_sheet time: mean',
#  'comment': 'The total calving flux over land ice is a spatial integration of '
#             'the calving flux',
#  'dimensions': ['time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'giayr.tendlicalvf',
#  'label': 'giayr.tendlicalvf',
#  'long_label': 'Total Calving Flux',
#  'mip_tables': {'giayr': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'tendlicalvf',
#  'positive': '',
#  'standard_name': 'tendency_of_land_ice_mass_due_to_calving',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/acmonz.oxprod.json
# {'@context': '_context_',
#  'cell_measures': '',
#  'cell_methods': 'longitude: mean time: mean',
#  'comment': 'total production rate of o+o1d+o3 including o2 photolysis and all '
#             'o3 producing reactions',
#  'dimensions': ['latitude', 'plev39', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'acmonz.oxprod',
#  'label': 'acmonz.oxprod',
#  'long_label': 'Total Odd Oxygen (Ox) Production Rate',
#  'mip_tables': {'acmonz': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmosChem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'oxprod',
#  'positive': '',
#  'standard_name': 'tendency_of_mole_concentration_of_ox_in_air_due_to_chemical_and_photolytic_production',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmonlev.ficeberg.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'computed as the iceberg melt water  flux into the ocean divided '
#             'by the area of the ocean portion of the grid cell.',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmonlev.ficeberg',
#  'label': 'opmonlev.ficeberg',
#  'long_label': 'Water Flux into Sea Water from Icebergs',
#  'mip_tables': {'opmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'ficeberg',
#  'positive': '',
#  'standard_name': 'water_flux_into_sea_water_from_icebergs',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.cland.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'Report missing data over ocean grid cells. For fractional land '
#             'report value averaged over the land fraction.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.cland',
#  'label': 'lpmon.cland',
#  'long_label': 'Total Carbon in All Terrestrial Carbon Pools',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'cLand',
#  'positive': '',
#  'standard_name': 'mass_content_of_carbon_in_vegetation_and_litter_and_soil_and_forestry_and_agricultural_products',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obmon.fg13co2.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Gas exchange flux of carbon-13 as CO2 (positive into ocean)',
#  'dimensions': ['longitude', 'latitude', 'time', 'depth0m'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'obmon.fg13co2',
#  'label': 'obmon.fg13co2',
#  'long_label': 'Surface Downward Mass Flux of Carbon-13 as 13CO2 [kgC m-2 s-1]',
#  'mip_tables': {'obmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'fg13co2',
#  'positive': 'down',
#  'standard_name': 'surface_downward_mass_flux_of_13C_dioxide_abiotic_analogue_expressed_as_13C',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmon.fsitherm.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'computed as the sea ice thermodynamic water flux into the ocean '
#             'divided by the area of the ocean portion of the grid cell.',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmon.fsitherm',
#  'label': 'opmon.fsitherm',
#  'long_label': 'Water Flux into Sea Water Due to Sea Ice Thermodynamics',
#  'mip_tables': {'opmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean', 'seaIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'fsitherm',
#  'positive': '',
#  'standard_name': 'water_flux_into_sea_water_due_to_sea_ice_thermodynamics',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.ffirenat.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'CO2 emissions from natural fires',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.ffirenat',
#  'label': 'lpmon.ffirenat',
#  'long_label': 'Carbon Mass Flux into Atmosphere Due to CO2 Emission from '
#                'Natural Fire [kgC m-2 s-1]',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'fFireNat',
#  'positive': '',
#  'standard_name': 'surface_upward_mass_flux_of_carbon_dioxide_expressed_as_carbon_due_to_emission_from_natural_fires',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lisubhrptsite.sbl.json
# {'@context': '_context_',
#  'cell_measures': '',
#  'cell_methods': 'area: point time: point',
#  'comment': 'The snow and ice sublimation flux is the loss of snow and ice '
#             'mass per unit area from the surface resulting from their direct '
#             'conversion to water vapor that enters the atmosphere.',
#  'dimensions': ['site', 'time1'],
#  'dtype': 'real',
#  'frequency': 'subhrPt',
#  'id': 'lisubhrptsite.sbl',
#  'label': 'lisubhrptsite.sbl',
#  'long_label': 'Surface Snow and Ice Sublimation Flux',
#  'mip_tables': {'lisubhrptsite': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['landIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'sbl',
#  'positive': '',
#  'standard_name': 'tendency_of_atmosphere_mass_content_of_water_vapor_due_to_sublimation_of_surface_snow_and_ice',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/opmonlev.rsdo.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Downwelling radiation is radiation from above. It does not mean '
#             "'net downward'.  When thought of as being incident on a surface, "
#             "a radiative flux is sometimes called 'irradiance'.  In addition, "
#             'it is identical with the quantity measured by a cosine-collector '
#             "light-meter and sometimes called 'vector irradiance'.  In "
#             "accordance with common usage in geophysical disciplines, 'flux' "
#             "implies per unit area, called 'flux density' in physics.  "
#             "'shortwave' means shortwave radiation.",
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'opmonlev.rsdo',
#  'label': 'opmonlev.rsdo',
#  'long_label': 'Downwelling Shortwave Radiation in Sea Water',
#  'mip_tables': {'opmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocean'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rsdo',
#  'positive': 'down',
#  'standard_name': 'downwelling_shortwave_flux_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/simon.sidmassth.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'Total change in sea-ice mass from thermodynamic processes divided '
#             'by grid-cell area',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'simon.sidmassth',
#  'label': 'simon.sidmassth',
#  'long_label': 'Sea-Ice Mass Change from Thermodynamics',
#  'mip_tables': {'simon': {'mip_era': 'obs4mips'}},
#  'modeling_realm': ['seaIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'sidmassth',
#  'positive': '',
#  'standard_name': 'tendency_of_sea_ice_amount_due_to_sea_ice_thermodynamics',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.treefracndlevg.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land over all_area_types time: mean',
#  'comment': 'This is the percentage of the entire grid cell that is covered by '
#             'needleleaf evergreen trees.',
#  'dimensions': ['longitude', 'latitude', 'time', 'typetreene'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.treefracndlevg',
#  'label': 'lpmon.treefracndlevg',
#  'long_label': 'Needleleaf Evergreen Tree Area Percentage',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'treeFracNdlEvg',
#  'positive': '',
#  'standard_name': 'area_fraction',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '%',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/simon.sidmassmelttop.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'The rate of change of sea ice mass through melting at the ice '
#             'surface divided by grid-cell area',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'simon.sidmassmelttop',
#  'label': 'simon.sidmassmelttop',
#  'long_label': 'Sea-Ice Mass Change Through Surface Melting',
#  'mip_tables': {'simon': {'mip_era': 'obs4mips'}},
#  'modeling_realm': ['seaIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'sidmassmelttop',
#  'positive': '',
#  'standard_name': 'tendency_of_sea_ice_amount_due_to_surface_melting',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/simon.sidragbot.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello',
#  'cell_methods': 'area: time: mean where sea_ice (comment: mask=siconc)',
#  'comment': 'Oceanic drag coefficient that is used to calculate the oceanic '
#             'momentum drag on sea ice',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'simon.sidragbot',
#  'label': 'simon.sidragbot',
#  'long_label': 'Ocean Drag Coefficient',
#  'mip_tables': {'simon': {'mip_era': 'obs4mips'}},
#  'modeling_realm': ['seaIce'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'sidragbot',
#  'positive': '',
#  'standard_name': 'sea_ice_basal_drag_coefficient_for_momentum_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': '1',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/obyrlev.pop.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacello volume: volcello',
#  'cell_methods': 'area: mean where sea time: mean',
#  'comment': 'sum of particulate organic phosphorus component concentrations',
#  'dimensions': ['longitude', 'latitude', 'olevel', 'time'],
#  'dtype': 'real',
#  'frequency': 'yr',
#  'id': 'obyrlev.pop',
#  'label': 'obyrlev.pop',
#  'long_label': 'Mole Concentration of Particulate Organic Matter Expressed as '
#                'Phosphorus in Sea Water',
#  'mip_tables': {'obyrlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['ocnBgchem'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'pop',
#  'positive': '',
#  'standard_name': 'mole_concentration_of_particulate_organic_matter_expressed_as_phosphorus_in_sea_water',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'mol m-3',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/apmonlev.rsucs.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: time: mean',
#  'comment': 'Upwelling clear-sky shortwave radiation  (includes the fluxes at '
#             'the surface and TOA)',
#  'dimensions': ['longitude', 'latitude', 'alevhalf', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'apmonlev.rsucs',
#  'label': 'apmonlev.rsucs',
#  'long_label': 'Upwelling Clear-Sky Shortwave Radiation',
#  'mip_tables': {'apmonlev': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['atmos'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'rsucs',
#  'positive': 'up',
#  'standard_name': 'upwelling_shortwave_flux_in_air_assuming_clear_sky',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'W m-2',
#  'valid_max': '',
#  'valid_min': ''}
# /Users/daniel.ellis/WIPwork/MIP-variables/src-data/variables/lpmon.fnfert.json
# {'@context': '_context_',
#  'cell_measures': 'area: areacella',
#  'cell_methods': 'area: mean where land time: mean',
#  'comment': 'Total Nitrogen added for cropland fertilisation (artificial and '
#             'manure). Relative to total land area of a grid cell, not relative '
#             'to agricultural area',
#  'dimensions': ['longitude', 'latitude', 'time'],
#  'dtype': 'real',
#  'frequency': 'mon',
#  'id': 'lpmon.fnfert',
#  'label': 'lpmon.fnfert',
#  'long_label': 'Total Nitrogen Added for Cropland Fertilisation (Artificial '
#                'and Manure)',
#  'mip_tables': {'lpmon': {'mip_era': 'cmip6plus'}},
#  'modeling_realm': ['land'],
#  'ok_max_mean_abs': '',
#  'ok_min_mean_abs': '',
#  'out_name': 'fNfert',
#  'positive': '',
#  'standard_name': 'tendency_of_soil_mass_content_of_nitrogen_compounds_expressed_as_nitrogen_due_to_fertilization',
#  'themes': ['TBC'],
#  'type': ['wcrp:variables', 'variables'],
#  'units': 'kg m-2 s-1',
#  'valid_max': '',
#  'valid_min': ''}
